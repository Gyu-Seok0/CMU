# %% [markdown]
# # 11411/611 -NLP (S22)
# # Asssignment 3: Naive Bayes

# %% [markdown]
# Classifiers are helpful in distinguish texts from different categories. They are vey useful in numerous use cases.
#
# In this assignment you will build a Naive Bayes Classifier that will distinguish 6 different languages namely Hausa, Indonesisan, Manobo, Tagalog, Swahili and Nahuatl

# %% [markdown]
# You are required to program a Naive Bayes Classifier in this HW.
#
# Submission Guidelines
# Deadline:
#
# Programming:
#
# This notebook contains helpful test cases and additional information about the programming part of the HW. However, you are only required to submit naivebayes.py on Gradescope.
# We recommended that you first code in the notebook and then copy the corresponding methods/classes to naivebayes.py

# %%
from collections import defaultdict, Counter
from operator import itemgetter
from math import log
from typing import DefaultDict
import sys
import io

with open('./train.tsv') as f:
    train = [tuple(l.split('\t')) for l in f]
    
with open('./dev.tsv') as f:
    dev = [tuple(l.split('\t')) for l in f]

# %%
tmp=NaiveBayes()
map, mar, maf, mp, mr, mf=tmp.evaluate(train, dev, n=2)
# Out:
# vocab = {'haske babu', 'cike da', 'fitilar da', 'harapan ang', 'kata ganti', 'chake miguu', 'kapangyarihan para', 'sikan mamang', 'tingnan mo', 'atas na', 'katika maeneo', 'aking ama', 'wuya irin', 'nu no', 'nini hamkumkemea', 'iyan ogpagkablang', 'sa babilonia', 'kaso pero', 'keajaiban apa', 'dume na', 'kuniruhusu nipite', 'sa akin', 'babilonia na', 'wakuu ngambo', 'wanda kuka', 'yang akan', 'bada haskenta', 'mamang no', 'yesus memakai', 'tawa wanda', 'sebagai anak', 'irin tawa', 'jikinku ya', 'kalalakihan sa', 'kwa ajili', 'duhu ko', 'pilato okimatia', 'tunjukkan kepada', 'matumbo yake', 'yao njiani', 'buyag no', 'sikan iyan', 'kun ji', 'minsan lamang', 'ngozi ya', 'kamay sa', 'yang percaya', 'orang yang', 'a bisanku', 'miguu yake', 'no magsisibad', 'shan wuya', 'juu yenu', 'dì sikan', 'sampuù no', 'aking harapan', 'berkata kepadanya', 'berbicara bukan', 'yake na', 'ang hari', 'nake sha', 'kami untuk', 'kuka gani', 'na puno', 'magsisibad no', 'sha har', 'nakitaan nu', 'ng ubasan', 'haskenta a', 'kadan to', 'idan dukan', 'ganti untuk', 'hiyo sasa', 'kandin aw', 'itech omoxikovayah', 'ng isang', 'doosi kandin', 'tagapagalaga ng', 'hamkumkemea yeremia', 'mto ili', 'no nakitaan', 'to kabadbadanan', 'yoyote ya', 'tama ang', 'dengan berkata', 'ya mto', 'anathothi ambaye', 'menentang yesus', 'untuk nama', 'nyama pamoja', 'kita keajaiban', 'natuun din', 'gani wanda', 'babu duhu', 'hantod to', 'isang binigyan', 'ako ng', 'nipe barua', 'ambaye hujifanya', 'no buyag', 'kepada kami', 'nabii juu', 'ako ang', 'sasa kwa', 'berhak mengubah', 'dinggin ang', 'kamar fitilar', 'jikinku yana', 'kuna da', 'okimatia ke', 'omoxikovayah in', 'memakai huruf', 'por eso', 'no madoot', 'ang labanan', 'wanda kun', 'no harì', 'ini kata', 'para pemimpin', 'aw doosi', 'dan kan', 'ji nake', 'na ito', 'allah berhak', 'to sai', 'kan buyag', 'akan kamu', 'ito gagawin', 'zama kamar', 'ang tunay', 'binigyan ang', 'puno ng', 'ke in', 'na mabaki', 'kichwa chake', 'in jesús', 'ko kadan', 'absalom sa', 'mabuti at', 'bahwa kamukamudi', 'kaniya tingnan', 'yeremia wa', 'mengubah kebiasaankebiasaan', 'nipite katika', 'sa kaniya', 'maaalala mo', 'iyong kaso', 'karunungan upang', 'ya dume', 'to oglolobasan', 'in tlayakankeh', 'buktikan bahwa', 'jesús iva', 'aw isugba', 'njiani kwenda', 'oggagawangan dan', 'untuk membuktikannya', 'oglolobasan pad', 'itampendeza mfalme', 'may karunungan', 'ni absalom', 'eso okitemaktijkeh', 'no sampuù', 'kamukamudi ayat', 'ili wapate', 'agama yahudi', 'at hindi', 'ndipo nikamwambia', 'ogpagkablang duon', 'ang tagapagalaga', 'ngambo ya', 'su oggagawangan', 'walang isang', 'maipaliwanag nila', 'ama ang', 'madoot no', 'kwenda yuda', 'ikiwa itampendeza', 'na dalhin', 'kabadbadanan iyan', 'kamu tunjukkan', 'kecil karena', 'bukan orang', 'yahudi menentang', 'ubas at', 'wa anathothi', 'mabaki yoyote', 'ang iyong', 'wapate kuniruhusu', 'da haske', 'da take', 'para dinggin', 'mfalme nipe', 'duon kan', 'ya nyama', 'sa aking', 'to natuun', 'yesus sebagai', 'panaginip sa', 'ang aking', 'mo mabuti', 'mo ang', 'nila ang', 'kwa hiyo', 'aw hantod', 'ya zama', 'ang lahat', 'ajili ya', 'huruf kecil', 'dukan jikinku', 'tiopixkeh itech', 'pero walang', 'ayat ini', 'na mavi', 'isang atas', 'ng mga', 'tunay na', 'harì aw', 'mga kalalakihan', 'lahat ng', 'kaya nagbigay', 'kwa nini', 'na kichwa', 'dalhin sa', 'take bada', 'maeneo yao', 'buyag to', 'labanan at', 'ya wakuu', 'har yanzu', 'mfalme ikiwa', 'percaya kepada', 'yana cike', 'at ang', 'hari ng', 'kaya sasabihin', 'ng kapangyarihan', 'lamang at', 'no suwag', 'da shan', 'kepada yesus', 'pad kandin', 'ilagay mo', 'yake matumbo', 'nikamwambia mfalme', 'lalu para', 'iva por', 'hujifanya mwenyewe', 'madoot su', 'iyong kamay', 'tibò aw', 'at tama', 'at maaalala', 'ang panaginip', 'kebiasaankebiasaan kita', 'na may', 'upang maipaliwanag', 'kaniya minsan', 'suwag to', 'mavi yake', 'nagbigay ako', 'mwenyewe nabii', 'sai dukan', 'anak allah', 'kan madoot', 'karena yang', 'sasabihin ni', 'barua kwa', 'pemimpin agama', ' ...
# classes = {'nahuatl', 'indonesian', 'tagalog', 'manobo', 'hausa', 'swahili'}
# docs_by_class = defaultdict(<class 'list'>, {'swahili': [['kwa hiyo', 'hiyo sasa', 'sasa kwa', 'kwa nini', 'nini hamkumkemea', 'hamkumkemea yeremia', 'yeremia wa', 'wa anathothi', 'anathothi ambaye', 'ambaye hujifanya', 'hujifanya mwenyewe', 'mwenyewe nabii', 'nabii juu', 'juu yenu'], ['ndipo nikamwambia', 'nikamwambia mfalme', 'mfalme ikiwa', 'ikiwa itampendeza', 'itampendeza mfalme', 'mfalme nipe', 'nipe barua', 'barua kwa', 'kwa ajili', 'ajili ya', 'ya wakuu', 'wakuu ngambo', 'ngambo ya', 'ya mto', 'mto ili', 'ili wapate', 'wapate kuniruhusu', 'kuniruhusu nipite', 'nipite katika', 'katika maeneo', 'maeneo yao', 'yao njiani', 'njiani kwenda', 'kwenda yuda'], ['ngozi ya', 'ya dume', 'dume na', 'na mabaki', 'mabaki yoyote', 'yoyote ya', 'ya nyama', 'nyama pamoja', 'pamoja na', 'na kichwa', 'kichwa chake', 'chake miguu', 'miguu yake', 'yake matumbo', 'matumbo yake', 'yake na', 'na mavi', 'mavi yake']], 'manobo': [['dì sikan', 'sikan mamang', 'mamang no', 'no magsisibad', 'magsisibad no', 'no nakitaan', 'nakitaan nu', 'nu no', 'no sampuù', 'sampuù no', 'no suwag', 'suwag to', 'to kabadbadanan', 'kabadbadanan iyan', 'iyan sampuù', 'sampuù no', 'no harì', 'harì aw', 'aw sikan', 'sikan iyan', 'iyan ogpagkablang', 'ogpagkablang duon', 'duon kan', 'kan buyag', 'buyag no', 'no madoot', 'madoot su', 'su oggagawangan', 'oggagawangan dan', 'dan kan', 'kan madoot', 'madoot no', 'no buyag', 'buyag to', 'to natuun', 'natuun din', 'din tibò', 'tibò aw', 'aw hantod', 'hantod to', 'to oglolobasan', 'oglolobasan pad', 'pad kandin', 'kandin aw', 'aw doosi', 'doosi kandin', 'kandin aw', 'aw isugba']], 'tagalog': [['ilagay mo', 'mo ang', 'ang iyong', 'iyong kamay', 'kamay sa', 'sa kaniya', 'kaniya minsan', 'minsan lamang', 'lamang at', 'at maaalala', 'maaalala mo', 'mo ang', 'ang labanan', 'labanan at', 'at hindi', 'hindi na', 'na ito', 'ito gagawin'], ['ako ang', 'ang tunay', 'tunay na', 'na puno', 'puno ng', 'ng ubas', 'ubas at', 'at ang', 'ang aking', 'aking ama', 'ama ang', 'ang tagapagalaga', 'tagapagalaga ng', 'ng ubasan'], ['kaya sasabihin', 'sasabihin ni', 'ni absalom', 'absalom sa', 'sa kaniya', 'kaniya tingnan', 'tingnan mo', 'mo mabuti', 'mabuti at', 'at tama', 'tama ang', 'ang iyong', 'iyong kaso', 'kaso pero', 'pero walang', 'walang isang', 'isang binigyan', 'binigyan ang', 'ang hari', 'hari ng', 'ng kapangyarihan', 'kapangyarihan para', 'para dinggin', 'dinggin ang', 'ang iyong', 'iyong kaso'], ['kaya nagbigay', 'nagbigay ako', 'ako ng', 'ng isang', 'isang atas', 'atas na', 'na dalhin', 'dalhin sa', 'sa aking', 'aking harapan', 'harapan ang', 'ang lahat', 'lahat ng', 'ng mga', 'mga kalalakihan', 'kalalakihan sa', 'sa babilonia', 'babilonia na', 'na may', 'may karunungan', 'karunungan upang', 'upang maipaliwanag', 'maipaliwanag nila', 'nila ang', 'ang panaginip', 'panaginip sa', 'sa akin']], 'indonesian': [['lalu para', 'para pemimpin', 'pemimpin agama', 'agama yahudi', 'yahudi menentang', 'menentang yesus', 'yesus dengan', 'dengan berkata', 'berkata kepadanya', 'kepadanya buktikan', 'buktikan bahwa', 'bahwa kamukamudi', 'kamukamudi ayat', 'ayat ini', 'ini kata', 'kata ganti', 'ganti untuk', 'untuk nama', 'nama yesus', 'yesus memakai', 'memakai huruf', 'huruf kecil', 'kecil karena', 'karena yang', 'yang berbicara', 'berbicara bukan', 'bukan orang', 'orang yang', 'yang percaya', 'percaya kepada', 'kepada yesus', 'yesus sebagai', 'sebagai anak', 'anak allah', 'allah berhak', 'berhak mengubah', 'mengubah kebiasaankebiasaan', 'kebiasaankebiasaan kita', 'kita keajaiban', 'keajaiban apa', 'apa yang', 'yang akan', 'akan kamu', 'kamu tunjukkan', 'tunjukkan kepada', 'kepada kami', 'kami untuk', 'untuk membuktikannya']], 'hausa': [['idan dukan', 'dukan jikinku', 'jikinku yana', 'yana cike', 'cike da', 'da haske', 'haske babu', 'babu duhu', 'duhu ko', 'ko kadan', 'kadan to', 'to sai', 'sai dukan', 'dukan jikinku', 'jikinku ya', 'ya zama', 'zama kamar', 'kamar fitilar', 'fitilar da', 'da take', 'take bada', 'bada haskenta', 'haskenta a', 'a bisan ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/igyuseog/Desktop/CMU/NLP/HW03_Handout/naivebayes_handout.ipynb Cell 5' in <module>
#       <a href='vscode-notebook-cell:/Users/igyuseog/Desktop/CMU/NLP/HW03_Handout/naivebayes_handout.ipynb#ch0000004?line=0'>1</a> tmp=NaiveBayes()
# ----> <a href='vscode-notebook-cell:/Users/igyuseog/Desktop/CMU/NLP/HW03_Handout/naivebayes_handout.ipynb#ch0000004?line=1'>2</a> map, mar, maf, mp, mr, mf=tmp.evaluate(train, dev, n=2)
#
# /Users/igyuseog/Desktop/CMU/NLP/HW03_Handout/naivebayes_handout.ipynb Cell 6' in NaiveBayes.evaluate(self, train, eval, n)
#     <a href='vscode-notebook-cell:/Users/igyuseog/Desktop/CMU/NLP/HW03_Handout/naivebayes_handout.ipynb#ch0000005?line=189'>190</a> def evaluate(self, train: "list[tuple[str, str]]", eval: "list[tuple[str, str]]", n: int=2):
# --> <a href='vscode-notebook-cell:/Users/igyuseog/Desktop/CMU/NLP/HW03_Handout/naivebayes_handout.ipynb#ch0000005?line=190'>191</a>     log_prior, log_likelihood, classes, vocab = self.train_nb(train, n = n)
#     <a href='vscode-notebook-cell:/Users/igyuseog/Desktop/CMU/NLP/HW03_Handout/naivebayes_handout.ipynb#ch0000005?line=191'>192</a>     # Initialize dictionaries for true positives, false positives, and false negatives
#     <a href='vscode-notebook-cell:/Users/igyuseog/Desktop/CMU/NLP/HW03_Handout/naivebayes_handout.ipynb#ch0000005?line=192'>193</a>     tp, fp, fn = defaultdict(int), defaultdict(int), defaultdict(int)
#
# /Users/igyuseog/Desktop/CMU/NLP/HW03_Handout/naivebayes_handout.ipynb Cell 6' in NaiveBayes.train_nb(self, docs, k, n)
#     <a href='vscode-notebook-cell:/Users/igyuseog/Desktop/CMU/NLP/HW03_Handout/naivebayes_handout.ipynb#ch0000005?line=108'>109</a>         break
#     <a href='vscode-notebook-cell:/Users/igyuseog/Desktop/CMU/NLP/HW03_Handout/naivebayes_handout.ipynb#ch0000005?line=109'>110</a>         # log_likelihood[w][c] =
# --> <a href='vscode-notebook-cell:/Users/igyuseog/Desktop/CMU/NLP/HW03_Handout/naivebayes_handout.ipynb#ch0000005?line=110'>111</a> return log_prior, log_likelihood, classes, vocab
#
# NameError: name 'log_prior' is not defined
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Define A NaiveBayes class which is used to distinguish between languages using a character bigram model.

# Do create necessary variables wherever required.

import enum
import re

class NaiveBayes():
    def extract_ngrams(self,x: str, n=2) -> "list[str]":
        ###TODO###
        #extract character ngrams
        words = x.split()
        n_grams = []
        pattern_punctuation = re.compile(r'[^\w\s]') # only character + digit + space


        for i in range(len(words) - n + 1):
            n_gram = " ".join(words[i:i+n])
            input_string = n_gram.lower()
            output_string = pattern_punctuation.sub('', input_string)

            n_grams.append(output_string)

        return n_grams
        
    def smoothed_log_likelihood(self, w: str, c: str, k: int, count: 'DefaultDict[str, Counter]', vocab: "set[str]") -> float:
        ###TODO###
        #apply smoothing
        return 0
        

    def train_nb(self, docs: "list[tuple[str, str]]", k: int = 1, n: int = 2) -> "tuple[dict[str, float], DefaultDict[str, DefaultDict[str, float]], set[str], set[str]]":
        ###TODO###
        """
        Train a Naive-Bayes model

        :param docs: The documents, each associated with a clas label (document, label)
        :type docs: list[tuple[str, str]]
        :param k: The value added to the numerator and denominator to smooth likelihoods
        :type k: int
        :para n: the order of ngrams.
        :type b: int
        :return: The log priors, log likelihoods, the classes, and the vocabulary for the model at a tuple
        :rtype: tuple[dict[str, float], DefaultDict[str, DefaultDict[str, float]], set[str], set[str]]
        """
        ## Initialize vocab (the vocabulary) and docs_by_class (a dictionary in which
        ## class labels are keys and lists of documents are values).

        vocab = set()
        classes = set()
        docs_by_class = DefaultDict(list)

        ## Populate vocab and docs_by_class.

        for idx, (c, doc) in enumerate(docs): #class and doc
            #print(c,doc)
            
            ## Represent documents as collections of ngrams (default n=2)

            ngrams = self.extract_ngrams(doc)
            vocab |= set(ngrams)
            docs_by_class[c].append(ngrams)
            classes.add(c)

            if idx > 10:
                break
        '''
        print(f"vocab = {vocab}")
        print(f"classes = {classes}")
        print(f"docs_by_class = {docs_by_class}")
        exit()

        '''

        ## Total number of documents in the collection
        num_docs = len(docs)
        print("num_docs",num_docs)

        ## Number of documents in each class (with each label)
        num_docs_in_class = {key:len(value) for key,value in docs_by_class.items()}
        print("num_docs_in_class", num_docs_in_class)

        ## The log priors for each class

        # log_prior =

        ## Counts of times a label c occurs with an ngram w

        # count = 

        # log_likelihood = 

        for c, documents in docs_by_class.items():
            # Iterate over the documents of class c, accumulating <ngram, class> counts in counts

            for d in documents:
                for w in d:
                    break
                    # count[w][c]+=

            ## Calculate the number of documents with class label c
            # num_docs_in_class[c]= 

            ## Calculate the log prior as the log of the number of documents in class c over the total number of documents

            # log_prior[c] = 

            ## Calculate the log likelihood for each (w|c). Smooth by k=1.

            for w in vocab:
                break
                # log_likelihood[w][c] = 
        return log_prior, log_likelihood, classes, vocab

    def classify(self, testdoc: str, log_prior: "dict[str, float]", log_likelihood: "DefaultDict[str, DefaultDict[str, float]]", classes: "set[str]", vocab: "set[str]", k: int=1, n: int=2) -> str:
        ###TODO###
        """Given a trained NB model (log_prior, log_likelihood, classes, and vocab), returns the most likely label for the input document.

        :param textdoc str: The test document.
        :param log_prior dict[str, float]: The log priors of each category. Categories are keys and log priors are values.
        :param log_likelihood DefaultDict[str, DefaultDict[str, float]]: The log likelihoods for each combination of word/ngram and class.
        :param classes set[str]: The set of class labels (as strings).
        :param vocab set[str]: The set of words/negrams in the vocabulary.
        :param k int: the value added in smoothing.
        "param n int: the order of ngrams.
        :return: The best label for `testdoc` in light of the model.
        :rtype: str
        """
        ## Extract a set of ngrams from `testdoc`

        # doc =

        ## Initialize the sums for each class. These will be the "scores" based on which class will be assigned.

        # class_sum =

        ## Iterate over the classes, computing `class_sum` for each
        for c in classes:
            ## Initialize `class_sum` with the log prior for the class

            # class_sum[c] = 

            ## Then add the likelihood for each in-vocabulary ngram in the document

            for i, w in enumerate(doc):
                if w in vocab:
                    try:
                        # class_sum[c] = 
                        break
                    except ValueError:
                        break
                        # count = 
                        # count[w] = 
                        # log_likelihood[w][c] = 
                        # class_sum[c] = 

        return max(class_sum.items(), key=itemgetter(1))[0]
    
    def precision(self,tp: "dict[str, int]", fp: "dict[str, int]") -> float:
        return tp / (tp + fp)

    def recall(self,tp: "dict[str, int]", fn: "dict[str, int]") -> float:
        return tp / (tp + fn)

    def micro_precision(self, tp: "dict[str, int]", fp: "dict[str, int]") -> float:
        tp_sum = sum(tp.values())
        fp_sum = sum(fp.values())
        return tp_sum / (tp_sum + fp_sum)

    def micro_recall(self, tp: "dict[str, int]", fn: "dict[str, int]") -> float:
        tp_sum = sum(tp.values())
        fn_sum = sum(fn.values())
        return tp_sum / (tp_sum + fn_sum)

    def micro_f1(self, tp: "dict[str, int]", fp: "dict[str, int]", fn: "dict[str, int]") -> float:
        mp = self.micro_precision(tp, fp)
        mr = self.micro_recall(tp, fn)
        return 2 * (mp * mr) / (mp + mr)

    def macro_precision(self, tp: "dict[str, int]", fp: "dict[str, int]") -> float:
        n = len(tp)
        return (1 / n) * sum([self.precision(tp[c], fp[c]) for c in tp.keys()])

    def macro_recall(self, tp: "dict[str, int]", fn: "dict[str, int]") -> float:
        n = len(tp)
        return (1 / n) * sum([self.recall(tp[c], fn[c]) for c in tp.keys()])

    def macro_f1(self, tp: "dict[str, int]", fp: "dict[str, int]", fn: "dict[str, int]") -> float:
        n = len(tp)
        return 2 * (self.macro_precision(tp, fp) * self.macro_recall(tp, fn)) / (self.macro_precision(tp, fp) + self.macro_recall(tp, fn))

    def evaluate(self, train: "list[tuple[str, str]]", eval: "list[tuple[str, str]]", n: int=2):
        log_prior, log_likelihood, classes, vocab = self.train_nb(train, n = n)
        # Initialize dictionaries for true positives, false positives, and false negatives
        tp, fp, fn = defaultdict(int), defaultdict(int), defaultdict(int)
        confusion = defaultdict(lambda: defaultdict(int))
        for c_ref, doc in eval:
            c_hyp = self.classify(doc, log_prior, log_likelihood, classes, vocab, n = n)
            confusion[c_ref][c_hyp] += 1
            if c_ref == c_hyp:
                tp[c_ref] += 1
            else:
                fn[c_ref] += 1
                fp[c_hyp] += 1

        return self.macro_precision(tp, fp), self.macro_recall(tp, fn), self.macro_f1(tp, fp, fn), self.micro_precision(tp, fp), self.micro_recall(tp, fn), self.micro_f1(tp, fp, fn)

# %%
len(train)
train[0][1]
# Out:
# 'Kwa hiyo sasa, kwa nini hamkumkemea Yeremia wa Anathothi, ambaye hujifanya mwenyewe nabii juu yenu?\n'

# %%
dev
# Out:
# [('swahili',
#   'Dumu katika mambo haya. Maana kwa kufanya hivyo utajiokoa mwenyewe na wale wanaokusikiliza.\n'),
#  ('indonesian',
#   'Demikian juga dengan kita: Kita sendiri menganggap diri kita mati terhadap dosa dan bersatu dengan Kristus Yesus supaya kita hidup hanya bagi Allah saja.\n'),
#  ('swahili',
#   'Wakati Reu alipokuwa ameishi miaka thelathini na miwili, alimzaa Serugi.\n'),
#  ('manobo',
#   'su dagow malinggat a pad. Igpadaag ku ikow to madoyow no oghimuhon du-on to sinakupan to Diyus no piglikatan to kinabuhì ta su ita no sinakupan to Diyus, angod ki to tugdok aw sapat no pigbotangan to Diyus to katùtu-uhanan.\n'),
#  ('swahili',
#   'Ilitokea baada ya tauni ambayo BWANA alimwambia Musa na Eliazari mwana wa Haruni kuhani, Alisema,\n'),
#  ('indonesian',
#   '“Pergilah dan berdiri di salah satu teras Rumah Allah dan beritakanlah kepada orang-orang di sana ajaran tentang hidup yang baru itu.”\n'),
#  ('swahili',
#   'Kiangazi na joto huondoa barafu; ndivyo kuzimu pia kunavyowaaribu waliotenda dhambi.\n'),
#  ('swahili',
#   'Dishoni, Ezeri, na Dishani. Hizi zilikuwa koo the Wahori, wenyeji wa Seiri katika nchi ya Edomu.\n'),
#  ('swahili',
#   'Ilikuwa ni kwa imani kwamba Ibrahimu baada ya kujaribiwa, alimtoa Isaka. Ndiyo, yeye ambaye alipokea kwa furaha ahadi, alimtoa mwanawe wa pekee,\n'),
#  ('swahili',
#   'Ni lazima atatoa moja kila aina ya sadaka hizi kama sadaka iliyoletwa kwa Yahweh. Nayo itakuwa ya makuhani wanaonyunyizia damu ya sadaka ya amani kwenye madhabahu.\n'),
#  ('hausa',
#   'Mahaifin yaron da Mahaifiyarsa, sun yi mamaki kwarai domin abubuwan da aka fada akansa.\n'),
#  ('tagalog',
#   'Dumating sa akin ang Espiritu at itinayo ako sa aking mga paa; at nagsalita siya sa akin, at sinabi sa akin, "Pumunta ka at pagsarhan ang iyong sarili sa loob ng iyong bahay,\n'),
#  ('tagalog',
#   'Dahil binigyan mo ako ng lakas tulad ng sinturon para sa digmaan; inilagay mo ako sa ilalim ng mga nag-aalsa laban sa akin.\n'),
#  ('hausa',
#   'Ko, kuwa wane mutum ne a cikin ku, dan sa zai roke shi gurasa, ya ba shi dutse?\n'),
#  ('swahili',
#   'Kwa hiyo Hiramu akasema, "Ndugu yangu, ni miji gani hii uliynipatia? Hiramu akaiita nchi ya Kabuli mpaka leo.\n'),
#  ('swahili',
#   "Askari wake wakukodiwa ni kama dume la ng'ombe lililonona kati yake. lakini wao pia watageuka na kukimbia. Hawatasimama pamoja, kwani siku yao ya madhara inakuja kunyume chao, wakatik wa kuadhibiwa kwao.\n"),
#  ('tagalog',
#   'Gaya ng isang ulap na napapawi at nawawala, gayon din ang siyang bumababa sa sheol ay hindi na aahon pa.\n'),
#  ('manobo',
#   'Na mgo su-un ku, sikan ogdaa iyu no sinakupan to Diyus no Magbobo-ot ta no og-udlin iyu, ogtambag a iyu to ogpatahudan kandan.\n'),
#  ('tagalog',
#   'Sapagkat lahat ng mga propeta at ang kautusan ay patuloy na nagpapahayag hanggang kay Juan.\n'),
#  ('manobo',
#   'Sikan pagkatibuus to ginhawa now agad malisodan kow, ogpatugutan su sikan, ogpakapahogot to pagtu-u now aw kama-ani now to ogkaliyagan to Diyus no wadà ogboongon now.\n'),
#  ('hausa',
#   'Saboda haka, za a kwatanta mulkin sama da wani sarki da yake so ya lisafta dukiyarsa dake a hannun barorinsa.\n'),
#  ('tagalog',
#   'Dumaan kayo sa kahubaran at kahihiyan, mga taga-Safir. Huwag kayong lumabas mga taga-Zaanan. Nagdadalamhati ang Bethezel, sapagkat kinuha sa kanila ang proteksiyon.\n'),
#  ('swahili',
#   'Sasa wakati haya yote yalipokwisha, watu wote wa Israeli waliokuwepo pale wakaenda huko kwenye mji wa Yuda na wakazivunja vipande vipande nguzo za mawe na wakazikata nchi za maashera, na wakazibomoa sehemu za juu na madhabahu katika Yuda yote na Benyamini, na katika Efraimu na Manase, hadi walipoziharibu zote. Kisha watu wote wa Israeli wakarudi, kila mtu kwenye mali zake na kwenye mji wake.\n'),
#  ('tagalog',
#   'Dahil nagrebelde sila laban sa salita ng Diyos at tinanggihan ang tagubilin ng nasa Kataas-taasan.\n'),
#  ('manobo',
#   'Su ognangonan ku iyu to tùtu-u no sakup to Diyus, konà no otow no puli nigtuman to udyu-on aw to tùtu-u no ta-indanan to sakup to Diyus, konà no indan to lawa.\n'),
#  ('swahili',
#   'Yuda wote wakasimama mbele ya Yahwe, pamoja na wadogo wao, wake, na watoto.\n'),
#  ('tagalog',
#   'Sila ay nasa ilalim ng mga kautusan ng hari at mahigpit na kautusan ang ibinibigay sa mga mag-aawit na araw-araw kailangang gawin.\n'),
#  ('swahili',
#   'Roho wa Mungu akaja juu ya Zekaria mwana wa Yehoyada, yule kuhani; Zekaria akasimama juu ya watu na kusema kwao, "Mungu anasema hivi: Kwa nini mnazivunja amri za Yahwe, ili kwamba msifanikiwe? Kwa kuwa mmemsahau Yahwe, pia amewasahau ninyi."\n'),
#  ('tagalog',
#   'Dahil walang ala-ala tungkol sa iyo sa kamatayan. Sino ang magbibigay ng pasasalamat sa iyo sa sheol?\n'),
#  ('tagalog',
#   'Ang pangamba sa puso ng tao ay nagpapabigat sa kaniya, ngunit nagpapagalak ang mabuting salita.\n'),
#  ('nahuatl',
#   'Noijki tikmatih ke iKone in Dios ovala, iva otechmakak totlalnamikilis para ma tikixmatikah tlen yi neli Dios. Iva axka tikateh ivan tlen yi neli Dios, kijtosneki tikateh ivan iKone Jesucristo. Yen tlen yi neli Dios iva tlen techmaka nemilistli para semijkak.\n'),
#  ('hausa',
#   "Akwai wani almajiri a Dimashku mai suna Hananiya; sai Ubangiji ya yi magana da shi cikin wahayi, ya ce, ''Hananiya.'' Sai ya ce, ''Duba, gani nan Ubangiji.''\n"),
#  ('swahili', 'Wale walinzi walijawa na hofu na kuwa kama wafu.\n'),
#  ('hausa',
#   'sa\'annan ya kasa samun ninkin ba ninkin a duniyan nan, da rai na har abada a duniya mai zuwa."\n'),
#  ('swahili',
#   'ambao kwa sababu ya huo ninateswa hata kufungwa minyororo kama mhalifu. Lakini neno la Mungu halifungwi kwa minyororo.\n'),
#  ('tagalog',
#   '\'Ito ang sinasabi ni Yahweh: Hindi ninyo dapat nilulusob o nilalabanan ang inyong mga kapatid na bayang Israel. Bawat lalaki ay dapat magbalik sa kaniyang tahanan, dahil kalooban ko na mangyari ang bagay na ito."\' Kaya nakinig sila sa salita ni Yahweh at bumalik at nagpunta sa kani-kanilang daan, at sinunod nila ang kaniyang salita.\n'),
#  ('tagalog',
#   'Yahweh, Diyos ng aking kaligtasan, araw at gabi akong umiiyak sa iyo.\n'),
#  ('tagalog',
#   'Si Jesu- Cristo ay hindi nagbabago kahapon, ngayon at magpakaylan man.\n'),
#  ('tagalog',
#   'o kung hinampas siya sa galit gamit ang kaniyang kamay upang mamatay ang biktima, ang akusadong humampas sa kaniya ay tiyak na papatayin. Isang siyang mamamatay-tao. Ang kadugong tagapaghiganti ay maaaring patayin ang mamamatay-tao kapag siya ay makasalubong niya.\n'),
#  ('manobo',
#   'Nigdoyow on iyan to ginhawa noy su nadinog noy on to nahogot lagboy to pagtu-u now to Diyus no Magbobo-ot ta.\n'),
#  ('swahili',
#   'Nikasikia idadi ya wale waliotiwa muhuri: 144, 000, ambao walitiwa muhuri kutoka kila kabila ya watu wa Israel:\n'),
#  ('nahuatl',
#   'Ijkuak ayamo onikmatia tlen kijtova in tlanavatili, ne onikyejyekovaya kuali oninemia. Pero ijkuak onikixma in tlanavatili, in tlajtlakoli notech omoyoliti iva ne onixpolivik.\n'),
#  ('hausa',
#   'Akwai wata mace a nan wadda take zubar jini har shekara goma sha biyu. Ta kashe kudinta duka a wurin likitoci, domin su warkar da ita amma ba wanda ya iya warkar da ita.\n'),
#  ('swahili',
#   'na akasema "Ewe mwana wa Ibilisi, umejazwa na aina zote za udanganyifu na udhaifu. Wewe ni adui wa kila aina ya haki. Hautakoma kuzigeuza njia za Bwana, zilizonyooka, je utaweza?\n'),
#  ('hausa',
#   "Ta wurinsa ne duk wanda ya ba da gaskiya zai kubuta daga dukan abin da dokar Musa bata 'yantar da ku a kai ba.\n"),
#  ('tagalog',
#   'Nang ninais niyang dumaan sa Acaya, pinalakas ng mga kapatiran ang kaniyang loob at sumulat sa mga disipulo sa Acaya upang siya ay tanggapin. Nang dumating siya, tinulungan niya ng labis ang mga nanampalataya sa pamamagitan ng biyaya.\n'),
#  ('manobo',
#   'Su to mgo otow no nalimwasan on kandan to kalibutanon no kado-otan no pinabayà to pagkama-an dan bahin to Magbobo-ot ta no si Jesu-Kristu no Maglilipwasay ta dì matuu uli-on dan dà to tahan dan no paghimu aw kasakup dà ka-usab kandan to saà. To katapusan dan, dakoo on no kado-otan nasì du-on kan tugdow no paghimu no mado-ot.\n'),
#  ('indonesian',
#   '“Pada waktu itu kalau ada orang yang memberitahukan seperti ini, ‘Lihat! Kristus yang kita nanti-nantikan itu sekarang ada di sini,’ atau, ‘Dia ada di sana,’ jangan kalian percaya.\n'),
#  ('tagalog',
#   "Sapagkat ang lungsod na ito ay magiging kagalakan sa akin, isang awit ng papuri at karangalan para sa lahat ng bansa sa daigdig na makaririnig ng lahat ng mabubuting bagay na aking gagawin para dito. At manginginig sila dahil sa lahat ng mabubuting bagay at sa kapayapaang aking ibibigay dito.'\n"),
#  ('tagalog',
#   'Lumakad kasama ang mga matatalinong tao at ikaw ay magiging matalino, pero ang kasamahan ng mga mangmang ay magdurusa ng kapamahakan.\n'),
#  ('swahili',
#   'Walipokuwa wakipaza sauti, na kutupa mavazi yao na kutupa mavumbi juu,\n'),
#  ('tagalog',
#   'Siya ay maingay at magulo, ang kaniyang mga paa ay hindi mapanatili sa tahanan—\n'),
#  ('swahili', 'angalau niweze kuwa na matumaini katika ufufuo wa wafu.\n'),
#  ('swahili',
#   'Ahi mwana wa Abidieli mwana wa Guni, alikuwa kichwa cha familia ya baba yake.\n'),
#  ('manobo',
#   'Na, ogpakapa-andiya-on a to Hirusalim to Ispiritu Santu agad wadà ku kama-ani dow nokoy to ogkadoogan ku diyà.\n'),
#  ('swahili',
#   'Kwa hiyo, ndugu watakatifu, washiriki wa wito wa mbinguni, mumfikiri Yesu, Mtume na Kuhani Mkuu wa ukiri wetu.\n'),
#  ('swahili',
#   'Ndipo mimi, Danieli nilichoka sana na nikalala nikiwa dhaifu kwa siku kadhaa. Kisha nikainuka na nikaenda kufanya kazi za mfalme. Lakini nilikuwa nimetishwa sana na maono, na hapakuwa na mtu yeyote aliyeweza kuyaelewa.\n'),
#  ('indonesian',
#   'Lalu mereka memasuki kota itu dan pergi ke ruang atas— yaitu tempat di mana mereka menginap. Para rasul itu adalahPetrus, Yohanes, Yakobus,Andreas, Filipus, Tomas,Bartolomeus, Matius, Yakobus— yaitu anak Alfeus, Simon— orang yang dulu mengikuti gerakan Israel merdeka,gerakan Israel merdekaSecara harfiah, “Zelot”— yaitu nama gerakan tersebut.dan Yudas— yaitu anak Yakobus.\n'),
#  ('hausa',
#   'Bayan da Allah ya ta da bawansa, a gareku ne ya fara aiko shi, domin ya albarkace ku tawurin juyadda kowannenku daga muguntarsa."\n'),
#  ('swahili',
#   'Wewe uliwajibu, Yahwe Mungu wetu. Ulikuwa kwao Mungu mwenye kusamehe, lakini uliye adhibu matendo yao ya dhambi.\n'),
#  ('tagalog',
#   'Nagbigay din siya ng isang gintong pinggan na tumitimbang ng sampung siklo, na puno ng insenso.\n'),
#  ('hausa',
#   'Amma duk mutumin da ya ji kalmomina ya kuma ki biyayya da su, yana kamar mutum wanda ya gina gidansa a kan kasa, babu harshashi. Amma da ambaliyan ruwa ta buga gidan, nan take ya rushe, ragargajewar gidan kuma da girma take.\n'),
#  ('swahili',
#   'Hataingia kamwe mahali popote ambapo kuna maiti na kujitia unajisi, hata kama ni maiti ya baba yake au ya mama yake.\n'),
#  ('swahili', 'Hivyo tukaingia Yerusalem na kukaa humo kwa siku tatu.\n'),
#  ('tagalog',
#   'Kung naging mahirap ang kapwa ninyo Israelita at dahil doon ipinagbili ang ilan sa kanyang ari-arian, sa gayon maaaring bilhin muli ng pinakamalapit niyang kamag-anak ang ari-ariang ipinagbili niya sa inyo.\n'),
#  ('manobo',
#   'Dì niglingì si Jesus aw ikagi to “Iyu no mgo buyag no taga-Hirusalim, konà a now ogsinogawan. Iyan ogsinogawan now nasì to iyu no kabotang aw mgo kabata-an now.\n'),
#  ('tagalog',
#   'Nahihiga siya sa ilalim ng mga halamang tubig sa silungan ng mga talahib, sa putikan.\n'),
#  ('tagalog',
#   'Ngayon, sumulat ako sa inyo, mga minamahal, ang ikalawang sulat na ito ay upang gisingin ang inyong tapat na kaisipan,\n'),
#  ('swahili',
#   "Mara nyingine tena mnamo saa kumi na moja, alienda na kuwakuta watu wengine wamesimama bila kazi. Aliwaambia, 'kwanini mmesimama hapa bila kazi yoyote kwa siku nzima?\n"),
#  ('manobo',
#   'Kaling man nigpakabo-ot ad iyan to konà a og-usab oglo-uy iyu ko iyan ikapaduyong-ot now sikan to ginhawa now.\n'),
#  ('tagalog',
#   'Ngunit ibabalik ko ang kayamanan ng Moab sa mga huling araw. Ito ang pahayag ni Yahweh." Dito nagtatapos ang paghuhukom sa Moab.\n'),
#  ('tagalog',
#   'Inilapat niya ang turbante sa ibabaw ng kaniyang ulo, at sa ibabaw ng turbante, sa harapan, inilagay niya ang gintong plato, ang banal na korona, ayon sa ipinag-utos ni Yahweh sa kaniya.\n'),
#  ('tagalog',
#   'Sinabi niya sa kanila, "Ituon ang inyong mga isipan sa lahat ng mga salita na aking pinatunayan sa inyo ngayon, para mautusan ninyo ang inyong mga anak na sundin ang mga ito, ang lahat ng mga salita ng batas na ito.\n'),
#  ('manobo',
#   'Ko moydu-on oghimu to mado-ot dini ita, konà ta ogbaosan to mado-ot su dagow makalabow to kado-otan aw makasaad nasì to katuwadongan. Dì so-idi podon to oghimuhon ta nasì. Ogbaosan ta nasì to madoyow awos makalabow to katuwadongan. Dì to kado-otan, ogkada-og iyan.\n'),
#  ('manobo',
#   'Na intutuk dan si Jesus aw daduwa no ka-tulisan no pinagdibauy kandan.\n'),
#  ('tagalog',
#   'Nang matanda na si Samuel, ginawa niyang mga hukom sa Israel ang mga anak niyang lalaki.\n'),
#  ('tagalog',
#   'Pagkatapos dumating ang salita ni Yahweh kay Isaias, sinasabing,\n'),
#  ('swahili',
#   'Pia katika siku ya malimbuko, mtakapokuwa mnatoa sadaka ya unga mpya katika sikukuu zenu za Majuma, mtakuwa na kusanyiko takatifu la kumheshimu BWANA, na katika siku hiyo msifanye kazi zenu za kila siku.\n'),
#  ('swahili',
#   'Hivyo nimetabiri kama nilivyokuwa nimeamriwa; pumzi ikawajilia na wakaishi. Kisha wakasimama kwa miguu yao, jeshi moja kubwa sana.\n'),
#  ('tagalog',
#   'Kaya sinabi nila sa kaniya, "Nababaliw ka na."Ngunit kaniyang ipinilit na ito ay totoo. Kanilang sinabi, "Ito ang kaniyang anghel."\n'),
#  ('indonesian',
#   'Tetapi Yesus memanggil anak-anak itu dan berkata, “Biarkanlah anak-anak itu datang kepada-Ku dan jangan melarang mereka. Karena orang-orang yang seperti inilah yang menjadi warga kerajaan Allah.\n'),
#  ('hausa',
#   'Idan Dauda ya kira Almasihu \'Ubangiji,\' ta yaya ya zama dan Dauda?"\n'),
#  ('tagalog',
#   "Dalawampu't walong taong naghari si Jehu sa Israel sa Samaria.\n"),
#  ('swahili',
#   'Hukusikitika kuwa ameinajisi nchi, kwa hiyo wakatengeneza sanamu za mti na za jiwe.\n'),
#  ('tagalog',
#   'Tunay ngang pinakamaliit ang binhing ito sa lahat ng ibang mga binhi. Ngunit nang ito ay lumaki, naging mas malaki ito kaysa sa mga halamang panghardin. Ito ay naging puno kaya ang mga ibon sa himpapawid ay pumunta at namugad sa mga sanga nito."\n'),
#  ('swahili',
#   'Na yeyote aendaye mtaani nje ya milango ya nyumba yako,, damu yao itakuwa juu ya vichwa vyao na hatutakuwa na hatia yoyote. Lakini kama mkono utanyoshwa juu ya mtu yeyote aliye pamoja nawe katika nyumba, damu yake itakuwa juu ya vichwa vyetu.\n'),
#  ('indonesian',
#   '“Tetapi Aku kecewa dengan kalian karena hal ini: Beberapa dari antara kalian mengikuti ajaran sesat yang dulu diajarkan Bileam. Ingatlah bagaimana Bileam mengajari Balak untuk membujuk orang Israel supaya berbuat dosa— yaitu dengan ikut dalam pesta makan untuk menghormati berhala dan melakukan percabulan.Bil. 22:1–25:3, 31:16\n'),
#  ('manobo',
#   'Dayun natangkapan to nawnangonon to kanak, konà a ogkamatoy. Dì wadà din inangon to kanak no si Juan, konà a ogkamatoy. Dì puli din nasì innangon no nig-iling to “Agad pahaba-on ku to umuu din dow konà kotob to pag-ulì ku dini, dì wadà labot nu sikan.”\n'),
#  ('swahili', 'Sheria zako ni za ajabu, ndiyo sababu ninazitii.\n'),
#  ('tagalog',
#   'Tingnan ninyo, kayong lahat mismo ang nakakita nito; kung gayon bakit ninyo sinabi ang lahat ng mga walang katuturan na ito?\n'),
#  ('swahili',
#   'Nzige wakaenda nchi yote ya Misri na kuharibu sehemu zote. Hapajawai kuwa na kundi kama hilo la nzige juu ya nchi, hakuna kama tena kama hilo litawai kutokea.\n'),
#  ('tagalog',
#   'Kaya binigay sa kaniya ni Hezekias ang lahat ng pilak na natagpuan sa tahanan ni Yahweh at sa mga pananalapi sa palasyo ng hari.\n'),
#  ('indonesian',
#   'Pahlawan-pahlawan imanDengan ‘percaya penuh’ artinya yakin kepada Allah bahwa apa yang kita harapkan pasti akan kita terima— biarpun kita belum melihatnya.\n'),
#  ('tagalog',
#   'Alam na ni Onan na ang bata ay hindi kanya. Kapag sumisiping siya kasama ng asawa ng kanyang kapatid na lalaki, tinatapon niya sa lupa ang kanyang semilya upang hindi siya magkaroon ng anak para sa kanyang kapatid na lalaki.\n'),
#  ('tagalog',
#   'Kaya si Hilkias at ang lahat ng inutusan ng hari ay pumunta kay Hulda na isang babaeng propeta, ang asawa ni Sallum na anak ni Tokat na anak ni Hasra, ang tagapag-ingat ng kasuotan (nanirahan siya sa Jerusalem sa Ikalawang Distrito) at nakipag-usap sila sa kaniya sa ganitong paraan:\n'),
#  ('tagalog',
#   'kung hindi, ang isa na nakakarinig sa iyo ay magdadala ng kahihiyan sa iyo at ng masamang balita tungkol sa iyo na hindi mabibigyang katahimikan.\n'),
#  ('hausa',
#   'Bari alheri ya kasance tare da ku; bari salama ta karu ta wurin sanin Allah da na Yesu Ubangijinmu.\n'),
#  ('indonesian',
#   'Tetapi Yesus memegang tangan anak itu dan berkata, “Hai anak-Ku, bangunlah.”\n'),
#  ('tagalog',
#   'Nang buksan ng Kordero ang ikalawang selyo, narinig ko ang ikalawang buhay na nilalang na sinabi, "Halika!"\n'),
#  ('swahili',
#   "Sasa wanafanya dhambi zaidi na zaidi. Wanatengeneza sanamu za chuma kutoka kwenye fedha zao, sanamu kwa kadiri ya ufanisi wao, zote ni kazi ya mafundi. Watu wanasema juu yao, 'Watu hawa watoao dhabihu na kumbusu ndama.'\n"),
#  ('swahili',
#   'Alisimama nyuma yake karibu na miguu yake huku akilia. Tena alianza kulowanisha miguu yake kwa machozi, na kuifuta kwa nywele za kichwa chake, akiibusu miguu yake na kuipaka manukato.\n'),
#  ('tagalog', 'Pagkatapos, kinausap ni Yahweh si Moises. Sinabi niya,\n'),
#  ('swahili', 'Tena BWANA alinena na Musa. Akasema,\n'),
#  ('swahili',
#   'Walipokwenda kwenye nyumba ya Yahwe Yerusalem, wakuu wa mababa walijitoa kwa hiari kujenga nyumba.\n'),
#  ('swahili',
#   'Au je, itajulikanaje niimepata upendeleo machoni pako, mimi na watu wako? Haitakuwa kuwa tu kama ukienda nasi mimi na watu wako tutakuwa na utofauti na watu wengine wote waliopo katika uso wa dunia?"\n'),
#  ('tagalog',
#   'Susuriin ito ng pari upang makita kung ito ay mas malalim sa balat, at kung ang buhok doon ay naging puti. Kung gayon, dapat ipahayag ng pari na siya ay marumi. Ito ay isang nakakahawang sakit, kapag ito ay namuo sa bahagi kung nasaan ang pigsa.\n'),
#  ('tagalog',
#   'Kasama din ang kapitel sa dalawang haligi, malapit sa kanilang tuktok, ay nakapalibot ang dalawang daang nakahanay na granada.\n'),
#  ('hausa',
#   "Ibrahim ''ya ba da gaskiya ga Allah, kuma an lisafta mashi wannan a matsayin adalci.''\n"),
#  ('swahili',
#   'Hivyo Daudi hakuwatayari tena kulichukua sanduku la Yahwe katika mji wa Daudi. Badala yake, akaliweka kando katika nyumba ya Obedi Edomu Mgiti.\n'),
#  ('indonesian',
#   'Kalau masih mau bertengkar, alasan apa yang kamu pakai untuk merasa dirimu lebih baik dari saudara-saudari seiman yang lain? Pikirkanlah ini: Semua kemampuan yang kamu miliki hanyalah pemberian Tuhan saja. Jadi, kalau pemberian itu hanya karena kebaikan hati Allah, janganlah kamu menyombongkan diri— seolah-olah kamu mendapatkan itu karena kekuatanmu sendiri!\n'),
#  ('swahili',
#   'Wote ambao huzingatia miungu isiyofaa hukataa uaminifu wako wao wenyewe.\n'),
#  ('tagalog',
#   'Ang kaniyang mga anak ay babangon at tinatawag siyang pinagpala; ang kaniyang asawang lalaki ay pupurihin na nagsasabing,\n'),
#  ('indonesian',
#   'Lalu Dia pergi sedikit lebih jauh dari mereka, lalu sujud dan berdoa. Kata-Nya, “Ya Bapa-Ku, kalau bisa, janganlah biarkan Aku menjalani penderitaan ini!janganlah … menjalani penderitaan iniSecara harfiah, “jauhkanlah cawan ini daripada-Ku.” Tetapi janganlah terjadi seperti yang Aku kehendaki, melainkan jadilah seperti yang Engkau kehendaki.”\n'),
#  ('hausa',
#   'Sai ya ga sararin sama ya bude kuma wani tasa na saukowa, wani abu kamar babban mayafi yana saukowa zuwa duniya, ana zuro shi ta kusuryoyinsa hudu.\n'),
#  ('tagalog',
#   'Muling magagalak kay Yahweh ang mga api, at magagalak sa Ang Banal ng Israel ang mga mahihirap.\n'),
#  ('tagalog',
#   'Hindi dapat mangibabaw laban sa isang tao ang isang tanging saksi para sa anumang kasalan, sa anumang bagay siya nagkasala; sa bibig ng dalawang saksi, o sa bibig ng tatlong saksi, dapat mapatunayan ang anumang bagay.\n'),
#  ('manobo',
#   'Kaling man ogkasabutan ta to wadà makatu-un kandan to insahad to Diyus su wadà man pamantu-u.\n'),
#  ('manobo',
#   '“Aboy humina-at kow no mag-a-anad to tinu-uhan, no wadà now ibogoy to susi no igka-abli to nabotangan to nama-anan no lagboy katùtu-uhanan. Aw iyu, wadà kow sood kan nabotangan aw hognà pad konà now ogtugutan kan ogkaliyag ogsood podon du-on.”\n'),
#  ('tagalog',
#   '"Maraming mga babae ang gumawa ng mabuti, ngunit hinihigitan mo silang lahat."\n'),
#  ('nahuatl',
#   'Kuali xinemikah innavak tlen amo tlaneltokakeh. Iva ijkó, maski yejvah ma tlajtokah fiero de imejvah kemi oyeskia fiero inmoyelis, yejvah kittaskeh ke imejvah kuali tlen inkichivah iva kiweijkachivaskeh in toYejwatzi itech neká tonali ijkuak Cristo valmuikas iva kintlajtlanilis kuenta nochtin.\n'),
#  ('tagalog',
#   'Bumalik ang hangganan sa Rama, at pagkatapos sa pinatibay na lungsod ng Tiro. Pagkatapos lumiko ang hangganan sa Hosa at nagtapos sa dagat, sa rehiyon ng Aczib,\n'),
#  ('swahili',
#   'Unapaswa kufanya vivyo hivyo kwa punda wake; unapaswa kufanya vivyo hivyo na vazi lake; unapaswa kufanya vivyo hivyo kwa kila kitu alichopoteza Muisraeli mwenzako, kitu chochote alichopoteza na ukakipata; hautakiwi kujificha.\n'),
#  ('tagalog',
#   'Dahil si Jesu-Cristo na Anak ng Diyos na ipinahayag namin nina Silvanus at Timoteo sa inyo, ay hindi "Oo" at "Hindi." Kundi laging "Oo".\n'),
#  ('nahuatl',
#   'Tlen ichkameh iva tlen tentzomeh’Ijkuak iKone in Tlakatl valmuikas ivan nochtin iilvikaktlatitlanilvah, valmuikas ika imavissotlanex iva motlalis itech itekivajsiya tlen kipia mavissotlanextli.\n'),
#  ('hausa', 'Ga kariya ta zuwa masu zargi na,\n'),
#  ('nahuatl',
#   'In toTeko ma kimonekilti ma kiknomati itech neká tonali ijkuak valmuikas oksejpa. Te kuali tikmati ke ye sa tekitl miek otechpalevi ijkuak otikatkah Éfeso.\n'),
#  ('manobo',
#   'Na sikan no nawnangonon, nigtangkap diyà to kalongodan to Kapirna-um no lunsud.\n'),
#  ('tagalog', 'Huwag kayong mangangalunya.\n'),
#  ('indonesian',
#   'Ajaran Yesus tentang pajakSesudah Yesus dan kami kembali ke Kapernaum, tibalah waktu memberikan pajak tahunan untuk Rumah Allah.pajak tahunan untuk Rumah AllahSecara harfiah, “dua drakma.” Pajak ini bukan pajak pemerintah. Menurut Hukum Musa, setiap laki-laki Yahudi yang berusia 20 tahun ke atas harus membayar pajak sebanyak dua-dirham setahun untuk keperluan Rumah Allah di Yerusalem. Dua dirham itu (atau dalam uang Romawi— dua drakma) seperti upah pekerja untuk setengah hari. Orang-orang yang mengumpulkan itu datang kepada Petrus dan bertanya, “Apakah gurumu selalu membayar pajak tahunan untuk Rumah Allah atau tidak?”\n'),
#  ('nahuatl',
#   'Pero Jesús amo otlanankili. In wei tiopixki oksemi okitlajtlani:—Nimitznavatia ika itoka toTajtzin Dios tlen yolitok, techilvi tinochtin kox te tiCristo, iKone in Dios.\n'),
#  ('tagalog',
#   'Ito ang mga anak ni Ana: Sina Dishon at Aholibama, na babaeng anak ni Ana.\n'),
#  ('swahili', 'Baba humpenda Mwana na amempa vitu vyote mikononi mwake.\n'),
#  ('swahili',
#   'Wana amani nyingi, waipendao sheria yako; hakuna cha kuwatia mashakani.\n'),
#  ('manobo',
#   'Pagbuhaya gayod ni Jesus, namanlogwà on kandan to linobongan aw sood to Hirusalim aw mahan-ing to nakakita kandan.\n'),
#  ('tagalog',
#   'Kung naibigay na ni Joshua sa kanila ang kapahingahan, hindi na magsasalita ang Diyos tungkol sa ibang araw.\n'),
#  ('tagalog',
#   'Tapat ang Diyos na siyang tumawag sa inyo sa pakikipagtipon sa kaniyang Anak na si Jesu-Cristo na ating Panginoon.\n'),
#  ('indonesian',
#   'Aku sungguh-sungguh berkata kepadamu: Banyak nabi dan raja yang ingin melihat dan mendengar apa yang sekarang kamu lihat dan dengar. Tetapi berkat itu tidak diberikan kepada mereka.”\n'),
#  ('swahili',
#   'Jumla ya miji ambyo mtawapa Walawi itakuwa arobaini na nane. Mtawapa hiyo miji pamoja na maeneo yao ya malisho.\n'),
#  ('swahili',
#   'Wewe unaleta mashahidi wapya dhidi yangu na kuzidisha hasira zako dhidi yangu; wanishambulia na majeshi mapya.\n'),
#  ('hausa', 'Daga nan sai na je lardin Suriya da Kilikiya.\n'),
#  ('manobo',
#   'mgo panlibug, aw mgo ogpalibug aw mgo bantut aw mgo dumadakop to udipon, aw mgo gau-on aw mgo ogmatu-ud to gaù, aw agad intawa pad no ogpakalapas to impang-anad no matuwadong\n'),
#  ('swahili',
#   'Au kama yeyote akiapa bila kufikiri kwa midomo yake kufanya ubaya, au kufanya vyema kwa vyovyote vile mtu ameapa kwa haraka atakapotambua atakuwa na hatia kwa vitu hivyo.\n'),
#  ('swahili',
#   'na kusema, "Litukuzwa jina la Mungu milele na milele; kwa kuwa hekima na nguvu ni zake.\n'),
#  ('swahili',
#   'Wao walikuja kinyume na mimi katika siku ile ya dhiki yangu lakini Mungu alikuwa msaada wangu!\n'),
#  ('nahuatl',
#   'Miekeh gentejtih okiseguirovayah in Jesús, iva noijki okitokayah miekeh sivameh tlen otzajtziah iva ochokayah de neyolkokoli por Ye.\n'),
#  ('swahili',
#   'Daudi akamuliza, "Unatoka wapi?" Yeye akajibu, "Nimeponyoka kutoka kambi ya Israeli."\n'),
#  ('tagalog',
#   'Sinabi ni Delilah kay Samson, "Hanggang ngayon nilinlang mo ako at nagsabi sa aking nga kasinungalingan. Sabihin mo sa akin kung papaano ka malulupig." Sinabi ni Samson sa kaniya, "Kapag tinirintas mo ang pitong hibla ng aking buhok sa isang tela na nasa isang panghabi, at pagkatapos ipinulupot ito sa panghabi, magiging katulad ako ng sinumang tao."\n'),
#  ('swahili', 'na huko waliihubiri injili.\n'),
#  ('indonesian',
#   'Karena laki-laki tidak berasal dari perempuan, tetapi perempuanlah yang berasal dari laki-laki.\n'),
#  ('swahili',
#   'Wakafanya njama dhidi ya Amazia katika Yerusalimu, akakimbilia Lakishi. Akakimbia hadi Lakishi, lakini wakawatuma watu kumfuata hadi Lakishi na kumuua huko.\n'),
#  ('swahili',
#   'Moyo wangu unawaendea wakuu wa Israeli, pamoja na watu ambao walijitolea -tunambariki Bwana kwa ajili yao!\n'),
#  ('tagalog',
#   'Habang nakikipag-usap si Pedro sa kaniya, pumasok siya at natagpuan niya ang napakaraming tao na nagtipon-tipon doon.\n'),
#  ('nahuatl',
#   'Ipokyo in tlitl tlen kitlajyoviltijtos, nochipa tlejkotos para semijkak. Iva amo keman kipiaskeh nesevili nion tlajka nion yovak nochtin tlen kimavistiliskeh in amo kuali yolkatl ivan iixkopinkayo de tetl, iva nochtin tlen motekaviliskeh ma kintlalilikah ixneskayotl de itoka.\n'),
#  ('tagalog',
#   'Bumangon si Abimelech nang maaga at pinapunta ang lahat ng kanyang lingkod sa kanya. Sinabi niya ang lahat ng mga bagay na ito sa kanila, at matinding takot ang naramdaman ng kanyang mga lingkod.\n'),
#  ('swahili',
#   'Absalomu akaishi Yerusalem miaka miwili pasipo kuona uso wa mfalme.\n'),
#  ('swahili',
#   'Mungu asingeligundua hili? Kwa maana yeye anazijua siri za moyo.\n'),
#  ('tagalog',
#   'Sinabi ni Aaron kay Moises, "Oh aking panginoon, pakiusap, huwag mong ipataw ang kasalanang ito laban sa amin. Nagsalita kami nang may kahangalan, at nagkasala kami.\n'),
#  ('manobo',
#   'Kanunoy kad ogkadigloman su wadad on igkatang-ow du-on ikow. To ginong-ginong to pagsauhan, ampan on. To mgo nigpadatù du-on, nangkabantug on dini to babow to kalibutan aw tibò to timamanwa, nangkaluku to pag-iyan-iyan to iyu no kaboonganan no gau-on to piglikatan.\n'),
#  ('indonesian',
#   'Oleh karena itu, kita tidak lagi merasa ada perbedaan antara orang Yahudi— bangsa yang bersunat, dan orang yang bukan Yahudi— bangsa-bangsa yang tidak bersunat. Dan kita tidak lagi membeda-bedakan asal usul orang— baik bangsa asing atau bangsa yang jahat, maupun orang berkedudukan tinggi atau rendah sebagai budak. Tetapi hal yang terpenting bagi kita adalah bahwa kita semua sudah menjadi satu umat karena bersatu dengan Kristus!\n'),
#  ('swahili',
#   'Kisha Mefiboshethi mwana wa Sauli akashuka ili kumlaki mfalme. Hakuwa ameivalisha miguu yake wala kunyoa ndevu zake wala kufua nguo zake tangu siku mfalme alipoondoka hata siku aliporudi kwa amani.\n'),
#  ('tagalog',
#   'Dahil nagdadagdag siya ng pagrerebelde sa kaniyang kasalanan; pinapalakpak niya ang kaniyang mga kamay para inisin kami sa aming kalagitnaan; nagsasabi siya ng mga salita laban sa Diyos."\n'),
#  ('tagalog',
#   'Ang sabi ng babae sa kaniya, "Ginoo, bigyan mo ako ng tubig na ito para hindi na ako mauuhaw at hindi na pumunta dito para umigib ng tubig."\n'),
#  ('hausa',
#   'Yanzu, ga Sarkin zamanai, marar mutuwa, boyayye, Allah makadaici girma, da daukaka su tabbata a gare shi har abada abadin. Amin.\n'),
#  ('swahili',
#   'Au iambie ardhi, na itakufundisha wewe; samaki wa baharini watakutangazia wewe.\n'),
#  ('swahili',
#   'Bakini katika nyumba hiyo, kuleni na mnywe watakachokitoa, kwa maana mfanyakazi anastahili mshahara wake. Msihame kutoka nyumba hii kwenda nyingine.\n'),
#  ('tagalog',
#   'At sa ikalawang araw, ikaw ay mag-aalay ng lalaking kambing na walang kapintasan mula sa mga kambing bilang handog para sa kasalanan. Lilinisin ng mga pari ang altar gaya ng paglilinis nila sa pamamagitan ng toro.\n'),
#  ('tagalog',
#   'Subalit sa tuwing naisin nilang dakpin siya, natatakot sila sa mga tao sapagkat tinuturing siya ng mga tao na isang propeta.\n'),
#  ('swahili',
#   "Hivyo ndivyo atakavyomfanya huyo ng'ombe, kama alivyomfanya ng'ombe wa sadaka ya dhambi, atamfanyia vivyo hivyo huyu ng'ombe, kuhani atawafanyia upatanisho watu nao watasamehewa.\n"),
#  ('swahili',
#   'Hatima yangu iko mikononi mwako. Uniokoe mikononi mwa maadui zangu na wale wanao nifukuzia.\n'),
#  ('swahili',
#   'Uyageuze macho yangu dhidi ya kutazama mambo yasiyofaa; unihuishe katika njia zako.\n'),
#  ('nahuatl',
#   'Tlen akin vetzis ipan nin tetl, pojpostekis. Iva tla in tetl vetzis íkka ipa, kikuejkuechos.\n'),
#  ('tagalog',
#   'Kaya sinabi ni Balak sa kaniya, "Pakiusap sumama ka sa akin sa isang lugar kung saan makikita mo sila. Makikita mo lamang ang pinakamalapit sa kanila, hindi silang lahat. Doon isusumpa mo sila para sa akin."\n'),
#  ('swahili',
#   'Ndipo nitaweka aibu ya milele na fedheha juu yenu ambayo haitasahauliwa.\'"\n'),
#  ('tagalog',
#   'Nagsalita sila laban sa Diyos: Sabi nila, "Kaya ba talaga ng Diyos na maglatag ng lamesa para sa atin sa ilang?\n'),
#  ('swahili',
#   'Tazama! Sanduku la agano la Bwana wa nchi yote litavuka mbele yenu katika Yordani.\n'),
#  ('manobo',
#   'Na, si Jesus nig-ikagi to ma-agbot to “To ogtu-u kanak, konà no kanak dà to ogtu-uhan din, su ogtu-uhan din gayod to nigpa-andini kanak.\n'),
#  ('swahili',
#   'Ndipo nikawajibu, "Mungu wa mbinguni atatupa ufanisi. Sisi ni watumishi wake na tutaondoka na kujenga. Lakini huna sehemu, hakuna haki, na hakuna dai la kihistoria huko Yerusalemu."\n'),
#  ('tagalog',
#   'Kamumuhian kayo ng lahat dahil sa aking pangalan. Ngunit sinuman ang makapagtitiis hanggang huli, ang taong iyon ay maliligtas.\n'),
#  ('manobo',
#   'Pinabayà gayod to pagtu-u ni Moises to Diyus, pigbotad din to hinang no pighingadanan to Paglipas to Kado-otan aw pagwitik-witik to langosa du-on to habangan no ta-indanan to ogpalipasan to Diwata no Magpoponas du-on to mgo panganoy to mgo Isrili.\n'),
#  ('tagalog',
#   'Sapagkat si Juan ay pumunta sa inyo sa daan ng katuwiran, subalit hindi ninyo siya pinaniwalaan, samantalang ang mga maniningil ng buwis at mga nagbebenta ng aliw ay naniwala sa kaniya. At kayo, noong nakita ninyo na nangyari, hindi man lang kayo nagsisi pagkatapos nito upang maniwala sa kaniya.\n'),
#  ('tagalog',
#   '“Anak ng tao, ipaalam mo sa Jerusalem ang tungkol sa kaniyang mga gawang kasuklam-suklam,\n'),
#  ('swahili', 'Mtu mpumbavu hawezi kuyajua, wala mjinga kuyaelewa haya:\n'),
#  ('hausa',
#   'Domin Almasihu bai faranta wa kansa rai ba. Kamar yadda aka rubuta, "zagin da wadansu suka yi masa ya sauka a kaina."\n'),
#  ('swahili',
#   'Kaini akamwambia Yahwe, "Adhabu yangu ni kubwa kuliko uwezo wangu wa kustahimili.\n'),
#  ('hausa',
#   'Ba Adamu ne aka yaudara ba, amma macen ce aka yaudara cikin laifi.\n'),
#  ('manobo',
#   'Dì ogdangat so-idi dini kanak awos matuman to impasulat to Diyus to mgo maglilikwaday din no lagsoban din natodu-on bahin to pagmuwa kanak.” Na du-on na-oyowan kandin bali to mgo sakup din aw pamanlaguy kandan.\n'),
#  ('hausa',
#   'Sai ta dawo da sauri cikin dakin taro wurin sarki ta ce da shi, "Ina so ka ba ni kan Yahaya Mai Yin Baftisma a cikin tire."\n'),
#  ('manobo',
#   'Natibuus to ginhawa noy agad mahimu koy no tipig no otow dow bantugan. Kadoog koy nalimutan to kamuwahanan dì buhì koy dà man. Agad mabun-ug koy to kalisod, dì wadà koy man kamatoy.\n'),
#  ('swahili',
#   'Hata hivyo, katika Bwana, mwanamke hayupo peke yake pasipo mwanamume, au mwanamume pasipo mwanamke.\n'),
#  ('indonesian',
#   'Memang Allah mengatur segala sesuatu sesuai dengan apa yang sudah ditentukan dan dikehendaki-Nya. Dan kita pun ternyata sudah dipilih dari permulaan dunia untuk mewarisi hak sebagai umat-Nyadipilih …Frasa ini menerjemahkan satu kata dalam bahasa Yunani (“eklerothemen”) yang berarti “dipilih sebagai ahli waris.” Lihat Ef. 1:5, 1:18, 3:6; Rom. 9:14-17; Gal. 3:18, 4:1-7. melalui persatuan dengan Kristus.\n'),
#  ('swahili',
#   'Utakapovuna zao lako shambani mwako, na ukasahau kipande cha mbegu shambani, haupaswi kurudi na kukichukua; kinapaswa kuwa cha mgeni, cha yatima, au cha mjane, ili Yahwe Mungu wako akubariki katika kazi ya mikono yako.\n'),
#  ('tagalog',
#   'Pagkatapos nagsalita ang Paraon kay Jose, at sinabing, "Ang iyong ama at ang iyong mga kapatid na lalaki ay pumunta sa iyo,\n'),
#  ('tagalog',
#   'At inawit ng Israel ang awiting ito: "Bumukal ka, balon. Awitin ang tungkol dito.\n'),
#  ('tagalog',
#   'Dapat mong pahiran sila gaya ng pangpahid mo sa kanilang ama kaya makapaglilingkod sila sa akin bilang mga pari. Ang pagpapahid sa kanila ay magdudulot sa kanila na maging palagian ang kanilang pagpapari sa buong salinlahi ng kanilang bayan."\n'),
#  ('swahili', 'Malkiramu, Pedaya, Shenezari, Yekamia, Hoshama, na Nedabia.\n'),
#  ('nahuatl',
#   'Axka, xikpiakah kuidado imejvah mismo iva xikinkuidarokah iichkavah in toTeko, tlen Ye okinko ika iesso, iva in Tioijyotzintli omechtlali kemi intlajpixkeh.\n'),
#  ('swahili',
#   'Baraba alikuwa ni mtu ambaye amewekwa gerezani kwa sababu ya uasi fulani katika jiji na kwa kuua.\n'),
#  ('swahili',
#   'Kwa hiyo imewapasa kuzishika amri na sheria zangu zote; ni lazima mzitii ili kwamba ile nchi ambayo ninawaleta kuishi isiwatapike nyinyi.\n'),
#  ('tagalog',
#   'Sinabi ni Josue sa lahat ng mga tao, "Tingnan mo, ang batong ito ay magiging isang patotoo laban sa amin. Narinig nito ang lahat ng mga salita na sinabi ni Yahweh sa amin. Kaya ito ay magiging isang saksi laban sa inyo, kung ninyo ipagkakaila ang inyong Diyos."\n'),
#  ('nahuatl',
#   'Ijkuakó Jesús okinmilvi:—Nochtin imejvah innechkavaskeh noselti, porke itech Tiotlajkuiloli ijkuilitok: “Nikmiktis in tlajpixki iva in ichkameh xixiniskeh.”\n'),
#  ('tagalog',
#   'Nang malaman ni Mordecai ang lahat ng ginawa, pinunit niya ang kanyang mga damit at isinuot ang telang magaspang at mga abo. Lumabas siya sa gitna ng siyudad, at umiyak ng isang malakas at mapait na iyak.\n'),
#  ('swahili',
#   'Wafalme hawa walikuwa ni mfalme wa Yeriko, mfalme wa Ai iliyo karibu na Betheli,\n'),
#  ('hausa',
#   'Wannan ne rai madawwami: wato su san ka, Allah makadaici na gaskiya, da shi kuma wanda ka aiko, Yesu Almasihu.\n'),
#  ('nahuatl',
#   'Tonses, in Amo Kuali Tlakatl okilvi:—Tla yi neli tiiKone in Dios, xikilvi nin tetl ma mokuapa pan.\n'),
#  ('tagalog', 'Mga kapatid, ipanalangin ninyo rin kami.\n'),
#  ('tagalog',
#   "Ngunit noong hating gabi na ay may sumigaw, 'Tingnan ninyo ang lalaking ikakasal! Pumunta na kayo at salubungin siya.'\n"),
#  ('manobo',
#   'no angod to lawa din no impaghitugu din, no kandin to nigtangkap du-on to tibò no nangkabotad. Dì pigbo-otan to Diyus to ita no lawa ni Jesu-Kristu, oghimuhon ki to Diyus no ko og-ahà to mgo otow dini ita, si Jesus to ogkakita-an.\n'),
#  ('tagalog',
#   'At ang bahaging timog: sa timog ng Tamar hanggang sa katubigan ng Meriba-kades, ang batis sa Egipto hanggang sa Malaking Dagat at sa katimugang bahagi patungo sa timog.\n'),
#  ('tagalog',
#   'Kayo rin ay maging matiyaga; ayusin ninyo ang inyong mga puso, dahil ang pagdating ng Panginoon ay malapit na.\n'),
#  ('hausa',
#   'Bayan tuhumata, sun yi kudirin saki na, domin ban yi laifin da ya cancanci mutuwa ba.\n'),
#  ('tagalog',
#   'At nalaman ko na ang mga bahaging nakatakda para sa mga Levita ay hindi naibigay sa kanila, kaya naman mabilis nilang nilisan ang templo, ang bawat isa sa kani-kaniyang bukid, tulad din ng ginawa ng mga mang-aawit.\n'),
#  ('manobo',
#   'Lagboy pigpakasapadan dan to mgo punu-an aw kayan sabuki kandan su wadà man saà no ogkahibatan dan su ogkahadok to punu-an ko masamuk to kahan-ingan su pigsayà-sayà dan to Diyus no nakadoyow to pungkù.\n'),
#  ('nahuatl',
#   'Jesús ayamo okalakia kan altepetl, ok okatka kan Marta okinamikki.\n'),
#  ('swahili',
#   'Uwezo wa watu wa Israeli ulikua na nguvu zaidi dhidi ya Jabin mfalme wa Kanaani, hata walipomwangamiza.\n'),
#  ('hausa',
#   "Sai na ce, 'Duba, gani na zo in yi nufinka, kamar yadda aka rubuta akaina.'''\n"),
#  ('swahili',
#   'Nina ujasiri mwingi ndani yenu, na ninajivuna kwa ajili yenu. Nimejawa na faraja. Ninajawa na furaha hata katikati ya mateso yetu yote.\n'),
#  ('tagalog',
#   'Ito ang pamana na itinalaga ni Moises sa kanila sa mga kapatagan ng Moab, sa ibayo ng Jordan silangan ng Jerico.\n'),
#  ('swahili',
#   'Hakuna aliye muona mwingine; hakuna aliye toka nyumbani mwake kwa siku tatu. Walakini, Waisraeli wote walikuwa na taa katika sehemu walizo ishi.\n'),
#  ('tagalog',
#   'Pagkatapos, sinabi ni Jeremias, "Nagsalita si Yahweh tungkol sa inyo—ang natira ng Juda. Huwag kayong pumunta sa Egipto! Natitiyak ko na alam ninyo na ako ang naging saksi laban sa inyo ngayon.\n'),
#  ('tagalog',
#   'Isaalang-alang ang mga kabigatan ng isang bato at ang timbang ng buhangin, at ang pagpapagalit ng isang hangal ay mas mabigat kaysa sa dalawa.\n'),
#  ('indonesian',
#   'Menghormati Allah dalam perkataan dan janjiSaudara-saudari, hal ini sangat penting: Waktu kamu mengatakan sesuatu atau berjanji tentang sesuatu, janganlah menguatkan perkataan atau janjimu itu dengan bersumpah atas nama apapun. Jadi jangan menyebut surga atau bumi sebagai saksi atas sumpahmu. Kalau hal yang dibicarakan itu benar, cukup kamu katakan saja, “Ya, itu benar.” Kalau hal itu salah, katakan saja, “Itu tidak benar.” Karena setiap kali kamu berkata sesuatu dengan sumpah, Tuhan akan mengadili kamu kalau apa yang kamu sumpahkan itu tidak benar.Mat. 5:33-37\n'),
#  ('swahili',
#   'Majivuno yenu si kitu kizuri. Hamjui chachu kidogo huharibu donge zima?\n'),
#  ('indonesian',
#   'Tetapi kalian tidak boleh seperti mereka. Kalau di antara kalian ada yang mau menjadi orang yang terkemuka, dia harus mengambil tempat yang paling hina dan menjadi pelayan kalian.\n'),
#  ('hausa',
#   'In mutumin nan ba daga Allah yake ba, ba zai iya yin komai ba."\n'),
#  ('swahili',
#   'Yesu akawaambia, "Inawezekana mtu yeyote akawafanya waliohudhuria harusi ya Bwana Arusi kufunga wakati Bwana Arusi bado yu pamoja nao?\n'),
#  ('tagalog',
#   'Ang lahat ng nakatatanda ng Israel ay dumating, at ang mga pari ang kumuha ng arko.\n'),
#  ('tagalog',
#   'Ginawa niya ito para itaas ang mga mabababa; para ilikas ang mga taong nagdadalamhati sa mga abo.\n'),
#  ('swahili',
#   "Watoto watakaozaliwa katika kipindi cha msiba watasema mkiwa mnawasikiliza, 'Sehemu hii ni duni kwetu, tengeneza chumba kwa ajili yetu, ili tuweze kuishi hapa.\n"),
#  ('tagalog',
#   'At may isa pang tanda ang nakita sa langit. Tingnan mo! May isang malaking pulang dragon na may pitong ulo at sampung sungay, at may pitong korona sa kaniyang mga ulo.\n'),
#  ('swahili',
#   'Kwa hiyo nitawahamisha upande wa pili wa Damaskasi," asema Yahwe, ambaye jina lake ni Mungu wa majeshi.\n'),
#  ('tagalog',
#   'Nang narinig nila ang Batas, pinaalis nila mula sa Israel ang bawat dayuhan.\n'),
#  ('manobo',
#   'To sampuù tag duwa no soodanan no nahimuhan to tag songobu-uk no mutyà. Aw to mgo kalasada du-on tumaag buwawan no angod to pagaungan to kakillow.\n'),
#  ('tagalog',
#   'Dahil ikaw ang magiging saksi sa kaniya sa lahat ng mga tao tungkol sa iyong nakita at narinig.\n'),
#  ('tagalog',
#   'Tingnan ka nawa si Yahweh nang may kabutihang loob at bigyan ka ng kapayapaan.\'"\n'),
#  ('indonesian',
#   'Ketika anak itu sudah berumur seminggu,semingguSecarah harfiah, “delapan hari.” Kalau bayi laki-laki lahir pada hari Senin, maka dia disunat pada hari Senin berikutnya. Cara hitung orang Yahudi, hari pertama dan hari terakhir dihitung. Jadi dalam contoh di atas, hari Senin pertama dan yang terakhir dihitung, jadi jumlahnya delapan hari. banyak tamu yang datang menghadiri acara sunatan untuk anak itu. Mereka mau memberi nama Zakharia kepadanya— sesuai dengan nama bapaknya.\n'),
#  ('swahili',
#   'Yesu alipomwona, alimwita, akamwambia, "Mama, umewekwa huru kutoka kwenye udhaifu wako."\n'),
#  ('swahili',
#   'Ikiwa mmojawapo amechukuliwa mateka, na kwenye mateka ataenda. Ikiwa mmojawapo ataua kwa upanga, kwa upanga atauawa. Huu ni mwito wa utulivu na uvumilivu na imani kwa hao walio watakatifu.\n'),
#  ('tagalog',
#   'siya na gumawa sa Oso, sa Orion, sa Pleyades, at sa kumpol ng mga bituin sa katimugan.\n'),
#  ('swahili',
#   'Yule fahali kwaajili ya sadaka ya dhambi na mbuzi kwaajili ya sadaka za dhambi, ambaye damu yake ililetwa kufanya upatanisho katika mahali patakatifu, lazima ipelekwe nje ya kambi. kule lazima wachome, ngozi zao, nyama yao na kinyesi chao.\n'),
#  ('tagalog',
#   'Isama mo ang mga lalaking ito at linisin mo ang iyong sarili kasama nila, at bayaran ang mga gastusin nila, upang ahitin nila ang kanilang mga ulo. Upang malaman ng bawat isa na ang mga bagay na sinabi nila tungkol sa iyo ay mali. Malalaman nila na sumusunod ka rin sa kautusan.\n'),
#  ('swahili',
#   'Katika siku ya tisa ya mwezi wa nne wa huo mwaka, njaa ilikuwa kali sana kwenye huo mji kwamba hapakuwa na chakula kwa ajili ya watu wa nchi.\n'),
#  ('tagalog',
#   'Inilabas niya ang mga Israelita na may dalang pilak at ginto; walang sinuman sa kaniyang angkan ang natisod sa daan.\n'),
#  ('tagalog',
#   'Kung ang buong katawan ay mata, nasaan ang pakiramdam nang pandinig? Kung ang buong katawan ay tainga, nasaan ang pakiramdam nang pang-amoy?\n'),
#  ('swahili',
#   'Iwapo mwanamume kachukua mke, kisha kalala naye, na baadae kumchukia,\n'),
#  ('tagalog',
#   'Sinabi kay David ang anumang ginawa ni Rizpa, anak na babae ni Aya, ang asawang alipin ni Saul.\n'),
#  ('swahili',
#   'Mfalme akajibu, "Kimhamu atakwenda pamoja nami, nami nitamtendea kila lionekanalo jema kwako, na lolote unalotamani kutoka kwangu nitakutendea."\n'),
#  ('tagalog',
#   'At sinabi niya sa mga tao, "Naaayon ba sa batas ang gumawa ng mabuti sa Araw ng Pamamahinga o ang manakit; ang sumagip ng buhay o ang pumatay?" Ngunit tahimik ang mga tao.\n'),
#  ('swahili',
#   'Uzito wa misumari ulikuwa shekeli hamsini za dhahabu. Alizifunika sehemu za juu kwa dhahabu.\n'),
#  ('nahuatl',
#   'Iva yejón iknomachilistli otechmakak sa tlawel miek, otechmakak nochi tlayejyekoli iva tlamatilistli.\n'),
#  ('swahili',
#   'Kisha mfalme akageuka na kuwabariki mkusanyiko wa watu wa Israeli, wakati huo mkusanyiko wa Waisraeli walikuwa wamesimama.\n'),
#  ('swahili',
#   'Mimi nilisema, "Ninyi ni miungu, na ninyi nyote wana wa Mungu aliye Juu.\n'),
#  ('nahuatl',
#   'Ijkuak in gentejtih okittakeh in Jesús, nochtin okimotetzavijkeh iva omotlelojkeh okitlajpalotoh.\n'),
#  ('indonesian',
#   'Sesudah semua penderitaan itu selesai dijalani-Nya, maka sempurna dan lengkaplah pengalaman-Nya dalam pandangan Allah, sehingga Kristus menjadi Penyelamat dan sumber keselamatan untuk selamanya bagi setiap kita yang taat kepada-Nya.\n'),
#  ('tagalog',
#   'Ang kaniyang mga kasalanan ay patung-patong hanggang sa langit, at inalala ng Diyos ang kaniyang mga masasamang gawain.\n'),
#  ('indonesian',
#   'Saya tidak mengijinkan perempuan mengajar atau memerintah laki-laki. Waktu jemaat sedang diajar mereka harus tetap berdiam diri.\n'),
#  ('swahili',
#   'Na Mafarisayo walipokuwa bado wamejikusanya pamoja, Yesu aliwauliza swali.\n'),
#  ('swahili',
#   'Kichwa chako ni kama Karmeli; nywele kichwani mwako ni za zambarau nyeusi. Mfalme amestaajabishwa na vifundo vyake vya nywele.\n'),
#  ('tagalog',
#   'Palipas na ang gabi at malapit ng mag-umaga. Kaya iisantabi natin ang mga gawa ng kadiliman, at ating isuot ang baluti ng liwanag.\n'),
#  ('swahili',
#   'Sodoma dada yako hakutajwa hata kwa kinywa chako katika siku ulipojiinua,\n'),
#  ('nahuatl',
#   'Ijkuak in wei tiopixki iva in tlayakanki de templojmayoltih ivan tlen oksekimeh tlayakankeh tiopixkeh ijkuak ijkó okikakkeh, sa otlatlachixkeh iva omotlajtlaniayah kenomi nik tlamiti nin tlamantli.\n'),
#  ('tagalog',
#   'Hindi ba ito ang baso mula sa iniinuman ng aking amo, at ang baso na ginagamit niya para sa kanyang panghuhula? Gumawa kayo ng masama, ang bagay na ito na inyong ginawa."\'\n'),
#  ('hausa',
#   'Idan wani ya lalata haikalin Allah, Allah zai lalata shi. Gama haikalin Allah mai tsarki ne, kuma haka ku ke.\n'),
#  ('tagalog',
#   'Sinabi niya, "Kung mamarapatin ng hari, at kung nakasumpong ako ng kagandahang-loob sa iyong paningin, kung ang bagay ay parang wasto sa harap ng hari, at ako ay kalugud-lugod sa iyong mga mata, hayaang isang kautusan ang maisulat upang mapawalang-bisa ang mga liham ni Haman na anak ni Hammedatha na Agageo, ang mga liham na kanyang sinulat para wasakin ang mga Judio na nasa lahat ng mga lalawigan ng hari.\n'),
#  ('hausa',
#   "Sa'anda Bitrus da Yahaya suka bada shaida kuma suka fadi maganar Ubangiji, sun koma Urushalima; akan hanya, suka yi wa'azin bishara a kauyukan samariyawa da yawa.\n"),
#  ('tagalog',
#   'Paalalahanan sila wag manglait nang sinuman, iwasan ang pagtalo-talo, hayaan ang ibang mga tao sa kanilang pamamaraan, at magpakita ng kababaan ng loob sa lahat ng tao.\n'),
#  ('tagalog',
#   'Dahil marami ang naroroon sa kapulungan na hindi itinalaga ang kanilang mga sarili kay Yahweh, kaya ang mga Levita ang namahala sa pagkakatay ng korderong pampaskwa para sa lahat ng hindi nakapaglinis upang ilaan ang kordero kay Yahweh.\n'),
#  ('nahuatl',
#   'Ijkuakó in tlakah tlen tekipanovah itech barko okinekiah choloskeh, iva ope kitemoviah in barkojtzi itech atl kemi oyeskia koninkajkavah in tepostlatzikoltih ik iyakapan barko.\n'),
#  ('tagalog',
#   'Sumangguni si Haring Rehoboam sa mga matandang kalalakihan na nagpayo kay Solomon na kaniyang ama noong nabubuhay pa siya. sinabi niya, "Paano ninyo ako papayuhan upang mabigyan ng kasagutan ang mga taong ito?"\n'),
#  ('nahuatl', 'Jesús okiseli iva okikua inmixpa.\n'),
#  ('tagalog',
#   'Pakinggan mo ang aking dalangin, Yahweh, makinig ka sa akin, makinig ka sa aking pag-iyak! Huwag kang maging bingi sa akin, dahil tulad ako ng isang dayuhang kasama ninyo, isang nangibang-bayan tulad ng lahat ng aking mga ninuno.\n'),
#  ('swahili', 'katika Mungu ninaamini, sitaogopa. Yeyote atanifanya nini?\n'),
#  ('indonesian',
#   'Karena kalau kita menjual minyak itu, tentu kita akan mendapat uang yang banyak sekali,uang yang banyak sekaliSecara harfiah, “300 dinar.” Dinar adalah mata uang Romawi yang dibuat dari perak asli. Pada waktu itu, satu dinar adalah upah seorang pekerja dalam satu hari. Jadi 300 dinar hampir sama dengan upah seorang pekerja untuk satu tahun. lalu uang itu bisa kita bagi-bagikan kepada orang-orang miskin.”\n'),
#  ('indonesian',
#   'Paulus memberi salam kepada mereka dan menyampaikan laporan satu persatu tentang semua hal yang Allah sudah lakukan di antara orang yang bukan Yahudi melalui pelayanannya.\n'),
#  ('swahili',
#   'Watawatendeeni mambo haya yote kwa ajili ya jina langu kwa sababu hawamjui yule aliyenituma.\n'),
#  ('indonesian',
#   'Walaupun saya tidak bersama kalian, tetapi hati dan pikiran saya bersama kalian. Dan saya akan selalu senang waktu saya mendengar bahwa kalian hidup dengan teratur, dan masih terus kuat dalam hal percaya penuh kepada Kristus.\n'),
#  ('swahili',
#   'Mara moja na kwa yote, nimeapa kwa utakatifu wangu sitamdanganya Daudi:\n'),
#  ('hausa',
#   "Sa'anda suke tadda muryarsu, suna jefar da tufafinsu da kuma baza kura a iska,\n"),
#  ('manobo',
#   'Tibò no nakadinog ki Jesus, naboong-boongan dan to kandin pagsabut aw pagtabak gayod.\n'),
#  ('nahuatl',
#   'Imechontlajpalovah nochtin toknivah tlaneltokakeh. Ximotlajpalokah se ivan oksé ika se ixtlapipitzoli de tlasojtlalistli inavak Cristo.\n'),
#  ('tagalog',
#   'Nang marinig ni Balak na dumating na si Balaam, lumabas siya upang salubungin siya sa isang lungsod ng Moab sa Arnon, na nasa hangganan.\n'),
#  ('swahili',
# ...
#  ('swahili',
#   'Kuhani atachukua kiasi cha damu kwa kidole chake na kuweka katika pembe za madhabahu ya dhabihu ya kuteketezwa. Damu yote iliyobaki ataimwaga chini ya madhabahu.\n'),
#  ('indonesian',
#   'Tetapi Yesus melarang roh-roh jahat itu dengan keras supaya tidak memberitahukan tentang diri-Nya.\n'),
#  ('manobo',
#   'no konà no bugtì ko konà no kandin no si Jesus to niglipwas ita aw kapasaylu din to ita no saà.\n'),
#  ('hausa',
#   'Amma Bulus da Barnaba suka kade masu kurar kafarsu. Suka tafi garin Ikoniya.\n'),
#  ('manobo',
#   'Nig-ikagi si Jesus to “Ogka-uli-an kad on su nigtu-u ka kanak.”\n'),
#  ('hausa',
#   'Su bayin Almasihu ne? (Ina magana kamar ba ni cikin hankalina) na fi su ma. Na ma yi aiki tukuru fiye da su duka, shiga kurkuku fiye da kowa, a shan duka babu misali, a fuskantar haduran mutuwa da yawa.\n'),
#  ('swahili',
#   'Upande wa kusini kutakuwa na kambi ya Reubeni katika kundi lao. Kiongozi wa kundi la Reubeni ni Elizuri mwana wa Shedeuri.\n'),
#  ('tagalog',
#   "Maglalaan kayo ng isang bahagi para sa lungsod na limang libong siko ang lawak at dalawampu't limang libong siko ang haba, iyan ang magiging kasunod sa bahagi na nakalaan para sa banal na lugar. Magiging pag-aari ng buong sambahayan ng Israel ang lungsod na ito.\n"),
#  ('swahili',
#   'Tuma mwanamume mmoja kutoka kila jamaa ya kabila. Kila mwanamume awe kiongozi katika kabila lake."\n'),
#  ('swahili', 'Moto uliwaka kati yao; moto uliwaangamiza waovu.\n'),
#  ('nahuatl',
#   'Noijki velis kijtos: “Ma tikchivakah tlen amo kuali para ma viki tlen kuali.” Miekeh techpojpovah kijtovah ke tejvah ijkó titlamachtiah. Pero toYejwatzi kintlajyoviltis ijkó kemi moneki.\n'),
#  ('swahili',
#   'Lakini wewe, Bethlehemu Efrata, hata kama uko mdogo miongoni mwa koo za Yuda, kutoka kweko mmoja atakuja kwangu kutawala Israeli, ambaye mwanzo wake ni kutoka nyakati za kale, toka milele.\n'),
#  ('manobo',
#   'Nigtabak to mag-a-anad to kasugu-an to “Ogkalogonan now to Diyus no Magbobo-ot now to tibò no tu-un now no domdom aw tibò no pikii now, ginhawa now, aw mgo doson now tibò, aw oglogonan now to kapadihu now angod to paglogon to lawa now.”\n'),
#  ('manobo',
#   'Konà no angod to tahan dan no banwa no piglikatan dan to pigpangahà dan su ko angod podon sikan, moydu-on ogka-ugsudan dan aw ogpamang-ulì podon kandan diyà.\n'),
#  ('indonesian',
#   'Jadi, marilah kita berusaha dengan giat untuk melakukan apa yang mendatangkan damai di antara kita, dan apa yang bisa membangun rohani setiap orang.\n'),
#  ('hausa',
#   'Amma kamar yadda yake a rubuce, "Abubuwan da babu idon da ya gani, babu kunnen da ya ji, babu zuciyar da ta yi tsammanin sa, abubuwan da Allah ya shirya wa wadanda suke kaunarsa.\n'),
#  ('swahili',
#   "Kumbukeni neno ambalo niliwaambia, 'Mtumwa si mkuu kuliko bwana wake.' Ikiwa walinitesa mimi, watawateseni ninyi pia; Kama walishika neno langu, wangelishika la kwenu pia.\n"),
#  ('nahuatl',
#   '—Tlamachti, Moisés okijkuilo, tla se tlakatl omonamikti, ixpolivi iva amo okinpixki ipilvah ivan itonana, ikni in difunto kipia de monamiktis ivan iknosivatl para ivan kinpias ipilvah kemi oyeskia ipilvah in difunto.\n'),
#  ('hausa',
#   "Sai Istifanus ya amsa ya ce, ''Ya 'yan'uwa da ubanni, ku saurare ni, Allah Madaukaki ya bayyana ga ubanmu Ibrahim tun yana can kasar Mesofotamiya, kafin ma ya zauna a kasar Haran;\n"),
#  ('tagalog',
#   'Ang mensahero na pumunta upang tawagin si Micaias ay nagsalita sa kaniya, sinasabi, "Ngayon tingnan mo, ang mga salita ng mga propeta ay naghahayag ng mabubuting bagay sa hari na iisa ang sinasabi. Pakiusap hayaan mong ang iyong salita ay maging tulad ng salita ng isa sa kanila at sabihin mo ang mabubuting bagay."\n'),
#  ('tagalog',
#   'kung ganun ay pakiusap makinig ka mula sa kalangitan at patawarin ang kasalanan ng iyong bayang Israel; ibalik mo sila mula sa lupain na iyong binigay sa kanilang mga ninuno.\n'),
#  ('nahuatl',
#   'Por eso, ijkuak ne nias ompa, nimechilvis nochi tlen amo kuali tlen kichiva, porke techpojpojtinemi iva tlapojtinemi fiero de tejvah. Iva amo san yejón, sino noijki amo kineki kinselis in toknivah tlen ompa onajsih. Iva tlen kinekih kinseliskeh in toknivah, ye amo kinkavilia. Iva tlen teseliah ye kinkixtia para ayakmo semi invah ma povikah in tlaneltokakeh.\n'),
#  ('swahili',
#   'Basi Yahwe alileta. Alifanya kama alivyoamrisha, kwani ninyi watu mmefanya dhambi dhidi yake na hamkutii sauti yake. Hii ni sababu ya jambo hili limetokea kwenu. Lakini sasa tazama!\n'),
#  ('swahili',
#   'Basi, wakampelekea Yesu, wakatandika nguo zao juu ya mwana punda na wakampandisha Yesu juu yake.\n'),
#  ('tagalog',
#   "Tumugon sila at sinabi, 'Kami ay mga lingkod ng nag-iisang Diyos ng langit at lupa, at muli naming itinatayo ang tahanang ito na itinayo ng dakilang hari ng Israel maraming taon na ang nakalilipas at binubuo namin ito.\n"),
#  ('tagalog',
#   'Sa kadahilanang ito, magdadalamhati ang lupain at ang kalangitan sa itaas ay magdidilim. Sapagkat inihayag ko ang aking mga layunin, hindi ko ito babawiin, hindi ko tatalikuran ang pagpapatupad ng mga ito.\n'),
#  ('tagalog',
#   'Kung sinuman ang magtama ng mangungutya ay nag-aanyaya ng pag-abuso, at kung sinuman ang magtuwid ng masamang tao ay masasaktan.\n'),
#  ('tagalog',
#   'Maghanda ka sa pagkatay sa kaniyang mga anak, dahil sa kasalanan ng kanilang mga ninuno, upang hindi sila tumaas at makuha ang mundo at punuin ang buong daigdig ng mga lungsod.\n'),
#  ('swahili',
#   '"Ni nani huyo anaye jitokeza kama kukicha, mzuri kama mwezi, ana ng\'aa kama jua, uamasisha kama bendera ya jeshi?" Mpenzi wa mwanamke akizungumza mwenyewe\n'),
#  ('tagalog',
#   'Ipagtanggol mo ang aking kapakanan at tubusin ako; ingatan mo ako gaya ng ipinangako mo sa iyong salita.\n'),
#  ('indonesian',
#   'Tetapi saya tidak akan membanggakan apa pun— kecuali Tuhan kita Kristus Yesus yang disalibkan! Karena melalui Yesus disalibkan, bagi saya semua hal yang duniawi seperti sudah ikut disalibkan pada kayu salib-Nya, dan seperti saya juga sudah mati bersama Dia terhadap semua hal yang duniawi.\n'),
#  ('swahili',
#   'kwa maana tazama, niko tiyari kumweka mahali mchungaji katika nchi. Hataangalia kondoo wanaoangamia. Hatatafuta kondoo wapoteao, wala kuwaponya kondoo wachechemeao. Hatawalisha kondoo wenye afya, lakini atakula nyama ya kondoo walionona naye atapasua kwato zao.\n'),
#  ('swahili',
#   'Kwa nyongeza, yeyote anaenda ndani ya nyumba wakati imefungwa atakuwa najisi mpaka jioni.\n'),
#  ('tagalog',
#   'Ngayon ang Espiritu ni Yahweh ay umalis na kay Saul, at sa halip isang masamang espiritu na mula kay Yahweh ang bumagabag sa kanya.\n'),
#  ('swahili',
#   'Kisha watamwona Mwana wa Adamu akija mawinguni katika nguvu na utukufu mkuu.\n'),
#  ('tagalog',
#   'Ngunit tumakas si Ismael na anak ni Netanias kasama ang walong kalalakihan mula kay Johanan. Pumunta siya sa mga Ammonita.\n'),
#  ('swahili',
#   'Bwana akamwambia, "Nitakuwa pamoja nawe, nawe utalishinda jeshi lote la Midiani kama mtu mmoja."\n'),
#  ('swahili',
#   'na waliitumia kwa shamba la mfinyanzi, kama Bwana alivyokuwa amenielekeza."\n'),
#  ('swahili',
#   "Wao pia hula nyumba za wajane, na wanajifanya wanasali sala ndefu. Hawa watapokea hukumu kubwa zaidi. '\n"),
#  ('manobo',
#   'Intabak ni Jesus to “Dow wadà kow makabasa du-on to kasulatan to Diyus to kapinunu-an pigbotad to Diyus to otow, lukos aw buyag no ogkasobu-uk\n'),
#  ('manobo',
#   'Dì labow-labow pad to kasing-otow ta du-on to buhì ta puli. Kaling man ogkatugutan ki to tinu-uhan ta to ogpabuligan ita to kasing-otow ta, agad adow on no konà no tigtatalabahu.”\n'),
#  ('tagalog',
#   'Ngayon ito ang mga utos, mga batas, at mga panuntunan na iniutos sa akin ni Yahweh na inyong Diyos para ituro sa inyo, para sundin ninyo ang mga ito sa lupain na inyong pupuntahan sa Jordan para angkinin;\n'),
#  ('nahuatl',
#   'Pero tla Cristo chanti itech imejvah, inmotonal kipia nemilistli porke toYejwatzi imechita yi intlakamelajkeh, maski inmokuerpo ixpolivis por yen tlajtlakoli.\n'),
#  ('tagalog',
#   'Pagkatapos, pumunta sila sa bulwagan ng hari at ibinalita ang mga salitang ito sa kaniya. Ngunit una nilang inilagay ang kasulatang balumbon sa silid ng kalihim na si Elisama.\n'),
#  ('swahili',
#   'Kila sdaka utakayoindaa na kuitoa itafanyika kama ilivyoanishwa hapa.\n'),
#  ('swahili',
#   'Mungu hutoa ushindi mkuu kwa mfalme wake, na yeye huonyesha uaminifu wa agano lake kwa mpakwa mafuta wake, kwa Daudi na ukoo wake milele.\n'),
#  ('nahuatl',
#   'Satepa isoldadojvah in Pilato okivikakeh in Jesús kan palacio, iva nochtin soldadojtih okiyavalojkeh.\n'),
#  ('manobo',
#   'su kandin to napa-atubangan to intag-an to maglilikwaday no lagsoban to Diyus natodu-on su nighina-at kandin to igbayà to Imananan to Ka-otawan. Nasulat to maglilikwaday to kagi to Diyus no pig-iling to ‘Ahà ka su ogpa-unahan ku ikow to kanak maglilikwaday awos din mahina-at to igbayà nu.’\n'),
#  ('tagalog',
#   'Dahil si Jesus mismo ay naghirap, noong siya ay tinukso, kaya niyang tulungan ang mga natukso.\n'),
#  ('manobo',
#   'Tinakin kan pigsoodan to busow no otow, piglapugad nasì kan mgo anak ni Iskiba aw kangkada-og din. Aw mamakalaguy kandan no nangkalobasan tibò kandan aw kangkapali-i pad kandan.\n'),
#  ('tagalog',
#   'Kinuha ni Saul si David na maglingkod sa kanya sa araw na iyon; hindi niya siya hinayaang bumalik sa bahay ng kanyang ama.\n'),
#  ('swahili',
#   'Kisha Malaika wa Yahwe akamwambia, "Nitazidisha uzao wako maradufu, kiasi kwamba watakuwa wengi wasioweza kuhesabika."\n'),
#  ('indonesian',
#   'Yesus meratapi kehancuran YerusalemKetika Yesus semakin dekat dengan Yerusalem, Dia memandang kota itu lalu meratapinya,\n'),
#  ('tagalog',
#   'Ngunit gaya ng isang babaing taksil sa kaniyang asawa, pinagtaksilan mo ako, sambahayan ng Israel. Ito ang pahayag ni Yahweh."\n'),
#  ('swahili',
#   'Alisimama akayapigia kelele majeshi ya Israeli, "Kwa nini mmekuja na mmejipanga kwa ajili ya vita? Mimi si Mfilisti, na ninyi si watumishi wa Sauli? Chagueni mtu kutoka kwenu ateremke na kuja kwangu.\n'),
#  ('tagalog', 'Pinaalis sila ni Galio sa hukuman.\n'),
#  ('swahili',
#   "Hivyo mtumwa alianguka, akapiga magoti mbele yake, akisema, 'Bwana, uwe na uvumilivu pamoja nami, na nitakulipa kila kitu.'\n"),
#  ('swahili',
#   'Ninaagiza kwamba katika utawala wote wa ufalme wangu watu watetemeka na kumcha mbele ya Mungu wa Danieli, kwa kuwa ni Mungu aliye hai na huishi milele, na ufalme wake hauwezi kuharibiwa; utawala wake utakuwepo hadi mwisho.\n'),
#  ('tagalog',
#   'Sa pamamagitan ito ng pananampalataya na si Abraham pagkatapos subuking ialay si Isaac. Oo siya na masayang tumanggap ng mga pangako ay inialay ang kaniyang nag-iisang anak,\n'),
#  ('tagalog',
#   'Sinabi ng lalaki kay Eli, "Ako ang isang nanggaling mula sa hanay ng labanan. Tumakas ako mula sa labanan sa araw na ito." At sinabi niya, "Ano ang nangyari, anak ko?"\n'),
#  ('nahuatl',
#   'Satepa de Teudas omonexti Judas tlen de Galilea, mero ijkuak omochi censo, iva noijki okinyakanki miekeh, pero noijki okimiktijkeh, iva nochtin tlen okitokayah oxixinkeh.\n'),
#  ('tagalog',
#   'Maraming kang nakikitang mga bagay, pero hindi nauunawaan; ang mga tainga nila ay nakabukas, pero walang nakaririnig.\n'),
#  ('swahili',
#   'Mzee wa Siku alipokuja, na watu watakatifu wa Mungu Aliye Juu Sana. Ndipo wakati ulipowadia ambapo watu watakatifu waliupokea ufalme.\n'),
#  ('indonesian',
#   'Jawaban itu membuat mereka lebih marah lagi, sehingga mereka mencari jalan untuk membunuh Dia. Karena menurut mereka, Dia sudah melanggar peraturan Musa tentang Hari Sabat, dan juga berkata bahwa Allah adalah Bapa-Nya. Berarti Dia membuat diri-Nya sama dengan Allah.\n'),
#  ('tagalog',
#   'Dahil isang apoy ang nag-aalab sa pamamagitan ng aking galit at sumusunog hanggang sa pinakamalalim na lugar ng mga patay; kinakain nito ang mundo at ang ani nito; sinusunog nito ang mga pundasyon ng mga bundok.\n'),
#  ('tagalog', 'Ang lahat na inyong ginagawa ay gawin sa pag-ibig.\n'),
#  ('tagalog',
#   'Isang malawak na daanan ang naroroon at tinawag iyon na Ang Banal na Daan. Hindi makapaglalakbay dito ang marumi. Pero ito ay magiging sa kaniya na maglalakad dito. Walang hangal ang makapupunta dito.\n'),
#  ('swahili', 'Hafaraimu, Shioni, na Anaharathi.\n'),
#  ('nahuatl', 'Porke tlen tlavelkualani amo kichiva tlen toYejwatzi kineki.\n'),
#  ('swahili',
#   'Vikombe vyote vya kunywea vya mfalme Sulemani vilikuwa vya dhahabu. Na vikombe vyote vya kunywea vya ikulu ya mwitu wa Lebanoni vilikuwa vya dhahabu safi. Hapakuwepo na kikombe cha fedha, kwa sababu fedha haikuwa na thamani katika siku za Sulemani.\n'),
#  ('swahili',
#   'Jairi mwana wa Manase alienda kuiteka miji yake na kuiita Havothi Jairi.\n'),
#  ('tagalog',
#   'Nang makita ng mga tao ng Ammon na sila ay naging isang masangsang na amoy kay David, nagpadala ng mga sugo ang mga tao ng Ammon at inupahan ang mga Arameo sa Bet Rehob at Soba, mga dalawampung libong sundalong naglalakad, at kasama ni haring Maaca ang isang libong kalalakihan, at mga tauhan ni Tob na may labindalawang libong kalalakihan.\n'),
#  ('hausa',
#   "Sa'adda suka zo wurin da a ke kira kwalluwa, nan suka giciye shi da barayin, daya daga hannun damansa dayan kuma daga hannun hagu.\n"),
#  ('manobo',
#   'Kaling man no nalabot kow to mgo panalangin to Diyus, og-oyowan now to tibò no mado-ot likat dini to kalibutan angod to paghilabot to duma, aw maw-oy, aw ibog no mado-ot, aw pagka-akom su pagka-akom to otow angod to nahimu no pinakadiyus din.\n'),
#  ('hausa',
#   'Saboda haka ya zama dole, daya daga cikin wadanda suke tare da mu tun lokacin da Ubangiji Yesu yana shiga da fita, a tsakaninmu,\n'),
#  ('swahili',
#   'Katika eneo hilo, walikuwapo wachungaji walioishi mashambani wakilinda makundi ya Kondoo wao usiku.\n'),
#  ('tagalog',
#   'Sinabi ni Moises sa mga Levita, "Itinalaga kayo sa paglilingkod kay Yahweh sa araw na ito, dahil bawat isa sa inyo ay kumilos laban sa kaniyang anak na kaniyang kapatid na lalaki, kaya bibigyan kayo ni Yahweh ng pagpapala sa araw na ito."\n'),
#  ('tagalog',
#   'Kaya mula noon kalahati ng aking mga lingkod ay nagtrabaho lamang sa pagtatayo muli ng pader, at kalahati sa kanila ay may hawak na mga sibat, panangga, mga pana at nagsuot ng kalasag, habang ang mga pinuno ay nakatayo sa likuran ng lahat ng mamamayan sa Juda.\n'),
#  ('tagalog',
#   'at hinimlay niya ito sa kaniyang bagong libingan na kaniyang inuka sa bato. Pagkatapos, pinagulong ang malaking bato at ipinangtakip sa pinto ng libingan at umalis.\n'),
#  ('swahili',
#   'Timiza juma la bibi arusi, na tutakupa yule mwingine pia kwa mbadala wa kunitumikia miaka mingine saba."\n'),
#  ('indonesian',
#   'Kami bersyukur karena kami sudah mendengar bahwa kalian terus percaya penuh kepada Kristus Yesus dan juga sangat mengasihi semua saudara kita— yaitu kita semua yang sudah disucikan oleh Dia.\n'),
#  ('nahuatl',
#   'Tlen amo judiojtih okiselijkeh in TioijyotzintliMientras Pedro ok otlapojtoka, ijkuakó in Tioijyotzintli ovala intech nochtin tlen okikaktokah itlajtol.\n'),
#  ('tagalog',
#   'Lumayo sila mula sa mga dayuhang diyus-diyosan na pag-aari nila at sinamba si Yahweh. At hindi na niya matiis ang paghihirap ng Israel.\n'),
#  ('swahili',
#   'Wakati huo - BWANA asema - wataleta kutoka makaburini mifupa ya wafalme wa Yuda na wakuu wake, mifupa ya makuhani na ya manabii na mifupa ya wakazi wa Yerusalemu.\n'),
#  ('indonesian',
#   'Kita tahu bahwa Hukum Taurat itu baik— asal kita mengajarkan Hukum Taurat itu sesuai dengan tujuan utamanya.\n'),
#  ('tagalog',
#   'Tumingin sa kanila ang lalaking pilay, na umaasang makatatangap ng anuman mula sa kanila.\n'),
#  ('nahuatl',
#   'Xikchivakah de xiekah ika yolsevilistli. Kada se ma kitta tlen de ye itekiv iva ma tekipano para kipias tlán kikuas, ijkó kemi tejvah yotimechnavatijkeh.\n'),
#  ('tagalog',
#   'Nang ang mga ito ay pumunta sa bahay ni Mikias at kinuha ang inukit na anyo, ang epod, mga pansambahayang diyos, at hinulmang metal na anyo, sinabi ng pari sa kanila, "Ano ang ginagawa ninyo?"\n'),
#  ('manobo',
#   'Na, monang ad nig-ulì diyà to Hirusalim no niglaboy pad to sampuù tag upat no tu-ig no iyan duma ku si Bernabe aw padumaha ku gayod si Tito.\n'),
#  ...]

# %%
tmp=NaiveBayes()
map, mar, maf, mp, mr, mf=tmp.evaluate(train, dev, n=2)

# %%
print(map, mar, maf, mp, mr, mf)
