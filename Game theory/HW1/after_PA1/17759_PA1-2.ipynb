# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# %cd /content/gdrive/My Drive/GT/PA1
# Out:
# /content/gdrive/My Drive/GT/PA1

# %% [markdown]
# **Installation**

# %%
# !pip install -e .
# !pip install cffi
# %cd /content/gdrive/My Drive/GT/PA1/onpolicy/envs/hanabi
# !mkdir build
# %cd build
# !cmake ..
# !make -j
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining file:///content/gdrive/My%20Drive/GT/PA1
# ...
#   Attempting uninstall: onpolicy
#     Found existing installation: onpolicy 0.1.0
#     Can't uninstall 'onpolicy'. No files were found to uninstall.
#   Running setup.py develop for onpolicy
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# /content/gdrive/My Drive/GT/PA1/onpolicy/envs/hanabi
# mkdir: cannot create directory ‘build’: File exists
# /content/gdrive/My Drive/GT/PA1/onpolicy/envs/hanabi/build
# CMake Deprecation Warning at CMakeLists.txt:1 (cmake_minimum_required):
#   Compatibility with CMake < 2.8.12 will be removed from a future version of
#   CMake.
#
#   Update the VERSION argument <min> value or use a ...<max> suffix to tell
#   CMake that the project does not need compatibility with older versions.
#
#
# -- Configuring done
# -- Generating done
# ...

# %%
# %cd /content/gdrive/My Drive/GT/PA1/onpolicy/scripts
# !pip install wandb
# !pip install tensorboardX
# Out:
# /content/gdrive/My Drive/GT/PA1/onpolicy/scripts
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# **Running Hanabi**

# %%
# !python3 /content/gdrive/MyDrive/GT/PA1/onpolicy/scripts/train/train_hanabi_forward.py --env_name "Hanabi" --algorithm_name "mappo" --experiment_name "exp2_KL" --hanabi_name "Hanabi-Very-Small"\
              --num_agents 2 --seed 4 --n_training_threads 1 --n_rollout_threads 1 --n_eval_rollout_threads 32 --num_mini_batch 2 --episode_length 300 --num_env_steps 90001\
                    --ppo_epoch 15 --gain 0.01 --lr 7e-4 --critic_lr 1e-3 --hidden_size 512 --layer_N 2 --use_eval --user_name woohyunc
# Out:
# choose to use gpu...
# wandb: Currently logged in as: woohyunc. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.13.4
# wandb: Run data is saved locally in /content/gdrive/MyDrive/GT/PA1/onpolicy/scripts/results/Hanabi/Hanabi-Very-Small/mappo/exp2_KL/wandb/run-20221012_190207-3hlzx12o
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run mappo_exp2_KL_seed4
# wandb: ⭐️ View project at https://wandb.ai/woohyunc/Hanabi
# wandb: 🚀 View run at https://wandb.ai/woohyunc/Hanabi/runs/3hlzx12o
# eval average score is 0.125.
#
#  Env Hanabi-Very-Small Algo mappo Exp exp2_KL updates 5/300 episodes, total num timesteps 1800/90001, FPS 51.
#
# average score is 0.08571428571428572.
#
#  Env Hanabi-Very-Small Algo mappo Exp exp2_KL updates 10/300 episodes, total num timesteps 3300/90001, FPS 52.
#
# average score is 0.21505376344086022.
#
# ...

# %%
3!python3 /content/gdrive/MyDrive/GT/PA1/onpolicy/scripts/train/train_hanabi_forward.py --env_name "Hanabi" --algorithm_name "mappo" --experiment_name "exp1" --hanabi_name "Hanabi-Very-Small"\
              --num_agents 2 --seed 4 --n_training_threads 1 --n_rollout_threads 1 --n_eval_rollout_threads 32 --num_mini_batch 1 --episode_length 100 --num_env_steps 30001\
                    --ppo_epoch 15 --gain 0.01 --lr 7e-4 --critic_lr 1e-3 --hidden_size 512 --layer_N 2 --use_eval
# Out:
# choose to use cpu...
# Traceback (most recent call last):
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/content/gdrive/MyDrive/GT/PA1/onpolicy/scripts/train/train_hanabi_forward.py", line 166, in <module>
#     main(sys.argv[1:])
#   File "/content/gdrive/MyDrive/GT/PA1/onpolicy/scripts/train/train_hanabi_forward.py", line 107, in main
#     reinit=True)
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_init.py", line 1098, in init
#     assert logger
# AssertionError
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.7/dist-packages/wandb/__main__.py", line 3, in <module>
#     cli.cli(prog_name="python -m wandb")
# ...
